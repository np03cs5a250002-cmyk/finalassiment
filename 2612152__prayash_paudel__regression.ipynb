# %% [markdown]
# <a href="https://colab.research.google.com/github/np03cs5a250002-cmyk/finalassiment/blob/main/2612152__prayash_paudel__regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: prayash paudel
#
# Student ID:2612152
#
# For Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df= pd.read_csv("/content/drive/MyDrive/global_climate_energy_2020_2024.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Energy consumption is the most serious global issue, which is directly related to the climate change, industrialization, and sustainable development. Proper forecasting of the energy demand is critical to the effective management of resources, policy planning and mitigation of environmental impacts. The objective of the project is to establish machine learning regression models capable of forecasting energy usage depending on climatic and socioeconomic characteristics. The models seek to capture seasonal variations, nonlinear relationships, and important drivers of energy demand and therefore help in making better decisions in the energy planning.
#
# The dataset is accessed from online Kaggle. The dataset is the global_climate_energy_2020_2024.csv, which contains 36540 rows and 10 columns. The dataset is grouped by 3 months, so its shape changed into 420 rows and 12 columns. Its input features is average temperature, humidity, CO₂ emissions, renewable energy share, urban population, industrial activity index, and energy price whereas target variable is energy consumption.
# This regression task is aligned with the United Nation Sustainable Development goals 7 which is Affordable and clean Energy and SDG 13 climate action.

# %% [markdown]
# performing EDA

# %%
# printing first 10 row
print("first 10 row are")
df.head(50)
df.shape
# Out:
# first 10 row are
# (36540, 10)

# %%
print(df['country'].unique())
# Out:
# ['Germany' 'France' 'Netherlands' 'Italy' 'Spain' 'Sweden' 'Norway'
#  'Poland' 'Turkey' 'United Kingdom' 'United States' 'Canada' 'Brazil'
#  'India' 'China' 'Japan' 'Australia' 'South Africa' 'Mexico' 'Indonesia']

# %%
df = df.rename(columns={'index': 'date'})

# %%
print(df.columns)
# Out:
# Index(['date', 'country', 'avg_temperature', 'humidity', 'co2_emission',
#        'energy_consumption', 'renewable_share', 'urban_population',
#        'industrial_activity_index', 'energy_price'],
#       dtype='object')

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df.head(50)

#here now date is sucessdully converted into valida date
# Out:
#          date  country  avg_temperature  humidity  co2_emission  \
# 0  2020-01-01  Germany            28.29     31.08        212.63
# 1  2020-01-02  Germany            28.38     37.94        606.05
# 2  2020-01-03  Germany            28.74     57.67        268.72
# 3  2020-01-04  Germany            26.66     51.34        167.32
# 4  2020-01-05  Germany            26.81     65.38        393.89
# 5  2020-01-06  Germany            27.81     32.92        644.48
# 6  2020-01-07  Germany            29.25     59.40        259.19
# 7  2020-01-08  Germany            28.90     55.12         76.08
# 8  2020-01-09  Germany            26.98     88.36        122.54
# 9  2020-01-10  Germany            27.05     31.19        253.33
# 10 2020-01-11  Germany            28.75     89.33        245.71
# 11 2020-01-12  Germany            28.32     48.71        704.67
# 12 2020-01-13  Germany            27.71     69.36        673.64
# 13 2020-01-14  Germany            29.47     67.07         98.61
# 14 2020-01-15  Germany            28.74     33.99        522.04
# 15 2020-01-16  Germany            28.60     88.14        567.84
# 16 2020-01-17  Germany            29.76     87.99        497.18
# 17 2020-01-18  Germany            28.52     30.67        392.93
# 18 2020-01-19  Germany            28.83     41.36        201.45
# 19 2020-01-20  Germany            29.24     67.17        639.19
# 20 2020-01-21  Germany            29.99     73.81        462.57
# 21 2020-01-22  Germany            27.68     60.46        396.19
# 22 2020-01-23  Germany            28.57     43.33        234.18
# 23 2020-01-24  Germany            26.67     49.90        509.11
# 24 2020-01-25  Germany            29.04     35.25        589.62
# 25 2020-01-26  Germany            29.40     57.38        297.26
# 26 2020-01-27  Germany            29.57     61.48         95.92
# 27 2020-01-28  Germany            29.12     78.86        699.09
# 28 2020-01-29  Germany            28.47     69.43        400.47
# 29 2020-01-30  Germany            26.73     73.36        603.23
# 30 2020-01-31  Germany            29.60     72.51        507.57
# 31 2020-02-01  Germany            30.68     78.87        871.14
# 32 2020-02-02  Germany            32.94     34.06        808.92
# 33 2020-02-03  Germany            29.58     78.53        861.99
# 34 2020-02-04  Germany            32.77     57.18        576.56
# 35 2020-02-05  Germany            32.49     42.64        903.97
# 36 2020-02-06  Germany            32.11     59.60        472.50
# 37 2020-02-07  Germany            34.58     66.09        449.06
# 38 2020-02-08  Germany            34.78     66.09        867.34
# 39 2020-02-09  Germany            30.55     55.14        468.12
# 40 2020-02-10  Germany            35.02     78.29        227.10
# 41 2020-02-11  Germany            32.66     63.17        518.97
# 42 2020-02-12  Germany            30.07     56.37        875.79
# 43 2020-02-13  Germany            33.14     67.02        200.46
# 44 2020-02-14  Germany            31.29     55.78        160.14
# 45 2020-02-15  Germany            30.68     40.64        503.84
# 46 2020-02-16  Germany            30.44     50.62        658.60
# 47 2020-02-17  Germany            29.79     75.74        780.70
# 48 2020-02-18  Germany            29.97     31.75        178.62
# 49 2020-02-19  Germany            30.48     30.11        917.78
#
#     energy_consumption  renewable_share  urban_population  \
# 0             11348.75            14.42             76.39
# 1              4166.64             5.63             86.26
# 2              4503.80            14.20             75.92
# 3              3259.13            13.84             63.15
# 4              7023.72             6.93             76.02
# 5             11955.99             7.08             78.71
# 6              4023.14             8.57             75.15
# 7              5582.50            12.40             65.77
# 8              7129.83             5.95             81.62
# 9              4006.50            12.56             85.80
# 10             1826.43            11.97             61.75
# 11            11142.89             7.38             88.69
# 12             4082.00            10.50             78.04
# 13             6209.55             9.04             61.31
# 14             9372.75             5.43             79.02
# 15             4222.41             9.89             89.61
# 16             7873.18            12.38             87.89
# 17             6818.65            10.65             86.08
# 18            11325.05            11.06             77.92
# 19             3711.64             5.49             70.40
# 20             6296.38            14.28             72.98
# 21             1701.11             6.71             88.92
# 22             9347.77             6.27             70.04
# 23             9811.14            12.90             81.17
# 24             3840.67            10.24             62.59
# 25             9874.91             5.68             67.38
# 26             9560.11            11.28             71.33
# 27             3613.73             9.77             73.74
# 28             8347.11             9.65             69.61
# 29             8650.00            11.81             71.27
# 30             7990.14            14.77             62.93
# 31             6768.59            10.07             63.06
# 32             1902.59            14.11             62.95
# 33            11751.94            14.87             80.81
# 34             9731.73             5.16             85.75
# 35             8058.80             8.28             84.89
# 36             4744.98             7.78             79.24
# 37            14916.15             9.04             63.26
# 38             6204.52            13.22             85.23
# 39             4047.52            12.29             63.48
# 40            12767.87             9.48             88.96
# 41             1885.76             5.03             86.02
# 42             2722.01            13.61             63.86
# 43             5040.88             9.58             87.12
# 44            13015.97            14.21             79.43
# 45             5868.49            13.09             78.31
# 46            14358.32             8.65             66.24
# 47             9986.24             6.25             79.65
# 48            13826.53            11.53             77.32
# 49            10015.62             9.60             70.66
#
#     industrial_activity_index  energy_price
# 0                       51.22         83.93
# 1                       78.27        110.40
# 2                       48.96        173.58
# 3                       97.42         89.13
# 4                       81.89         40.60
# 5                       78.70        128.62
# 6                       58.83         96.99
# 7                       56.95         70.62
# 8                       48.08         62.45
# 9                       70.89         32.50
# 10                      40.08        182.80
# 11                      65.67         98.55
# 12                      91.73         64.20
# 13                      69.46        169.26
# 14                      95.66        161.27
# 15                      80.82         36.74
# 16                      64.13        162.55
# 17                      78.04        118.72
# 18                      51.22         34.67
# 19                      92.49         84.28
# 20                      96.39         95.39
# 21                      69.63        144.60
# 22                      62.63         89.69
# 23                      54.19        129.29
# 24                      61.83        119.29
# 25                      57.11         91.84
# 26                      52.07        193.54
# 27                      71.11        195.12
# 28                      48.20         52.34
# 29                      97.36        175.57
# 30                      49.83        192.98
# 31                      99.06         49.45
# 32                      70.66        154.68
# 33                      78.30         70.29
# 34                      68.80        166.09
# 35                      91.67        164.51
# 36                      41.65        169.10
# 37                      97.64         64.82
# 38                      71.45        181.33
# 39                      41.33        145.43
# 40                      92.83        163.44
# 41                      89.87        191.62
# 42                      42.13        170.22
# 43                      54.43        155.26
# 44                      68.29         35.83
# 45                      97.52        170.47
# 46                      84.85         78.34
# 47                      54.95        129.35
# 48                      52.03        113.00
# 49                      52.27        104.05

# %% [markdown]
# here in our data set we have 20 unique country. it gave the value of climate energy of each country from 2020 to 2024. so i aggregate the day value in 3 monthly to make more better

# %%
# monthly aggragating per country
# Aggregate  monthly averages of energy consumption per country
monthly_df = (
    df.groupby('country')

    # resample means changing the frequency of time series
      .resample('3M', on='date')
      .mean()
      .reset_index()
)

print(monthly_df.head())
print("Rows after  monthly aggregation:", monthly_df.shape[0])

#extracting year and month from each date
monthly_df['year'] =  monthly_df['date'].dt.year
monthly_df['month'] = monthly_df['date'].dt.month

monthly_df.head(5)
monthly_df.shape
# Out:
# /tmp/ipykernel_2045/1217950027.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .resample('3M', on='date')
#      country       date  avg_temperature   humidity  co2_emission  \
# 0  Australia 2020-01-31        29.129032  59.520323    448.193226
# 1  Australia 2020-04-30        34.125556  57.612667    527.932556
# 2  Australia 2020-07-31        23.519457  60.837826    370.277935
# 3  Australia 2020-10-31        13.015326  56.183370    532.911304
# 4  Australia 2021-01-31        23.550652  59.619022    385.865870
#
#    energy_consumption  renewable_share  urban_population  \
# 0         5738.055484        11.165161         73.819032
# 1         7894.507556         9.401889         74.526111
# 2         6118.968804        10.565217         74.660217
# 3         8549.576848        10.057935         75.719565
# 4         5741.446522        10.764674         76.330000
#
#    industrial_activity_index  energy_price
# 0                  68.508710    119.663548
# 1                  71.499556    121.449556
# 2                  70.650109    115.577065
# 3                  67.387065    120.835000
# 4                  69.454239    116.773261
# Rows after  monthly aggregation: 420
# (420, 12)

# %%
#performing basic overview
print(monthly_df.head())
print(monthly_df.info())
print(monthly_df.isnull().sum())
print(monthly_df.describe())
# Out:
#      country       date  avg_temperature   humidity  co2_emission  \
# 0  Australia 2020-01-31        29.129032  59.520323    448.193226
# 1  Australia 2020-04-30        34.125556  57.612667    527.932556
# 2  Australia 2020-07-31        23.519457  60.837826    370.277935
# 3  Australia 2020-10-31        13.015326  56.183370    532.911304
# 4  Australia 2021-01-31        23.550652  59.619022    385.865870
#
#    energy_consumption  renewable_share  urban_population  \
# 0         5738.055484        11.165161         73.819032
# 1         7894.507556         9.401889         74.526111
# 2         6118.968804        10.565217         74.660217
# 3         8549.576848        10.057935         75.719565
# 4         5741.446522        10.764674         76.330000
#
#    industrial_activity_index  energy_price  year  month
# 0                  68.508710    119.663548  2020      1
# 1                  71.499556    121.449556  2020      4
# 2                  70.650109    115.577065  2020      7
# 3                  67.387065    120.835000  2020     10
# 4                  69.454239    116.773261  2021      1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   country                    420 non-null    object
#  1   date                       420 non-null    datetime64[ns]
#  2   avg_temperature            420 non-null    float64
#  3   humidity                   420 non-null    float64
#  4   co2_emission               420 non-null    float64
#  5   energy_consumption         420 non-null    float64
#  6   renewable_share            420 non-null    float64
#  7   urban_population           420 non-null    float64
#  8   industrial_activity_index  420 non-null    float64
#  9   energy_price               420 non-null    float64
#  10  year                       420 non-null    int32
#  11  month                      420 non-null    int32
# dtypes: datetime64[ns](1), float64(8), int32(2), object(1)
# memory usage: 36.2+ KB
# None
# country                      0
# date                         0
# avg_temperature              0
# humidity                     0
# co2_emission                 0
# energy_consumption           0
# renewable_share              0
# urban_population             0
# industrial_activity_index    0
# energy_price                 0
# year                         0
# month                        0
# dtype: int64
#                                 date  avg_temperature    humidity  \
# count                            420       420.000000  420.000000
# mean   2022-07-31 13:42:51.428571392        13.791807   59.958071
# min              2020-01-31 00:00:00        -5.459565   54.679783
# 25%              2021-04-30 00:00:00         7.159837   58.603757
# 50%              2022-07-31 00:00:00        13.279228   60.095027
# 75%              2023-10-31 00:00:00        20.571576   61.199496
# max              2025-01-31 00:00:00        34.403889   65.248033
# std                              NaN         9.387041    1.889547
#
#        co2_emission  energy_consumption  renewable_share  urban_population  \
# count    420.000000          420.000000       420.000000        420.000000
# mean     443.806958         7261.618104        15.846621         74.971805
# min      286.036721         5052.748587         8.850000         71.754839
# 25%      363.050163         6008.655924        12.451417         74.321277
# 50%      420.535594         6850.010000        15.963527         74.994076
# 75%      526.655679         8600.962418        19.425023         75.572506
# max      592.495109         9566.219130        22.731222         78.664839
# std       84.238554         1371.187465         4.335991          0.935424
#
#        industrial_activity_index  energy_price         year       month
# count                 420.000000    420.000000   420.000000  420.000000
# mean                   70.145893    115.308910  2022.142857    5.285714
# min                    64.710562    100.073804  2020.000000    1.000000
# 25%                    68.884647    112.057427  2021.000000    1.000000
# 50%                    70.080752    115.243487  2022.000000    4.000000
# 75%                    71.479133    118.498800  2023.000000    7.000000
# max                    75.033871    135.705806  2025.000000   10.000000
# std                     1.831955      5.067636     1.522644    3.414735

# %%
# handling those missing values
# first select the float and int value columns then Fill missing values in numeric columns with their mean
numeric_cols = df.select_dtypes(include=['float64','int64']).columns

for col in numeric_cols:
    df[col].fillna(df[col].mean(), inplace=True)
# Verify againA
print(df.isnull().sum())
# Out:
# date                         0
# country                      0
# avg_temperature              0
# humidity                     0
# co2_emission                 0
# energy_consumption           0
# renewable_share              0
# urban_population             0
# industrial_activity_index    0
# energy_price                 0
# dtype: int64
# /tmp/ipykernel_2045/3079423169.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)

# %%
# plotting the histogram to see if the consumption is normally distributed or skewed
sns.histplot(monthly_df['energy_consumption'], bins=30, kde=True)
plt.title("Distribution of 3 Monthly Energy Consumption")
plt.xlabel("energy_consumption")
plt.ylabel("value")
plt.show()

# %% [markdown]
# The distribution of weekly energy consumption is bimodal, with peaks around 6,000 and 8,500 units. This indicates two common usage levels, possibly reflecting seasonal or structural differences in demand. Understanding this distribution helps explain model behavior and guides feature engineering

# %%
plt.figure(figsize=(12,6))
for country in monthly_df['country'].unique()[:3]:  # plot first 3 countries
    subset = monthly_df[monthly_df['country'] == country]
    # here labels means each line plotted will be tagged for that country
    plt.plot(subset['date'], subset['energy_consumption'], label=country)

plt.legend()
plt.title("3 Monthly Energy Consumption Trends")
plt.xlabel("years")
plt.ylabel("energy consumption")
plt.show()

# %% [markdown]
# from above series plot chart we gave notice first 3 country chart how energy are consumption are chnages over a time.  here in x axis we have different years and in y axis we have energy consumption.<br>
#
#
# 1. Australia’s line  Appears relatively stable with moderate fluctuations
# 2. Brazil: Shows stronger swings, suggesting more pronounced seasonal or demand shifts.
#
# 3.  Canada: Also cyclical, but with slightly higher peaks compared to Australia.
#
# from overall it is observed that in some year brazil has become the most eergy consumption used country among these 3 countries.

# %%
corr = monthly_df[['avg_temperature','humidity','co2_emission',
                  'energy_consumption','renewable_share',
                  'urban_population','industrial_activity_index',
                  'energy_price']].corr()

          # here .corr() is computing the pearson correlation between every pair of numeric columns. we have 8 columns so it calculates the 8*8= 64 correlation


plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Climate & Energy Variables")
plt.show()

# %% [markdown]
# from above heatmap it displays the relationship between the input features and output like does higher temperature reduces the consumption. from abvove color we can understand that - Red → positive correlation (variables increase together).
# - Blue → negative correlation (one increases, the other decreases).
# - White/light → near zero correlation (no strong linear relationship).

# %%
# o=plotting the box plot to know if there is any outlier, what is central
sns.boxplot(x='month', y='energy_consumption', data=monthly_df)
plt.xlabel('Months')
plt.ylabel('Energy Consumption')
plt.title("3 Monthly Seasonality in Energy Consumption")
plt.show()

# %% [markdown]
# This box plot illustrates seasonal variation in monthly energy consumption. The median values show that April and October have higher energy use compared to January and July, which are lower. The wider boxes in April and October indicate greater variability, while the presence of outliers in January and July highlights unusual spikes or drops in demand. Overall, the plot reveals that energy consumption follows seasonal cycles, with transitional months (April and October) showing peaks and more fluctuation, while winter and summer months are relatively lower but more inconsistent.

# %%
target_corr = monthly_df[['avg_temperature','humidity','co2_emission',
                         'renewable_share','urban_population',
                         'industrial_activity_index','energy_price',
                         'energy_consumption']].corr()['energy_consumption']

print(target_corr)
plt.figure(figsize=(10,8))
sns.heatmap(target_corr.to_frame(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of input features vs energy consumption")
plt.show()
# Out:
# avg_temperature             -0.002379
# humidity                     0.027628
# co2_emission                 0.925301
# renewable_share             -0.044147
# urban_population            -0.062343
# industrial_activity_index    0.001948
# energy_price                -0.054154
# energy_consumption           1.000000
# Name: energy_consumption, dtype: float64

# %% [markdown]
# This heatmap shows how each input feature is related to energy consumption. The only strong relationship is with CO₂ emissions (about 0.93), meaning more energy use leads to more emissions. All other features like temperature, humidity, renewable share, population, industry, and price have correlations very close to zero, so they don’t show a strong direct effect. In short, CO₂ emissions are the most predictive feature, while the others may influence energy use in more complex or indirect ways

# %%
#scatter plot shows the relationship between 2 variables
#it shows relationahip between gni and hdi
#that straignt line represent the trend line or regssion line and if the data are closely clustered around the line then it has positive relation


if 'energy_consumption' in monthly_df:
  plt.figure(figsize=(8,6))
  sns.scatterplot(data= monthly_df,x='energy_consumption',y='co2_emission',marker='X',color='red')
  sns.regplot(data= df,
              x='energy_consumption',
              y='co2_emission',
              scatter=False)  #prints scatter line only\n",
  plt.title("Scatter plot of energy_consumption vs co2_emission"),
  plt.xlabel("energy_consumption",fontsize=12)

    # Label y-axis with HDI
  plt.ylabel("co2_emission",fontsize=12)
  plt.show()
else:
  print("energy_consumption is not available in dataset")

#- The line is drawn so that the sum of squared distances between the line and all the data points is as small as possible.

# %% [markdown]
# # Build a Primary Model  (Two Classical ML Models): <br>
# i will use linear regression and random forest regressor

# %%
# importing the necessary library for model building
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error

# %%
# here our target value is energu consumption so we will we y as energy consumption and x as other features
X_monthly = monthly_df[['avg_temperature','humidity','co2_emission',
               'renewable_share','urban_population',
               'industrial_activity_index','energy_price']]

Y_monthly = monthly_df['energy_consumption']

# %%
# performing the train test
# performing the train test split
X_train_monthly,X_test_monthly,Y_train_monthly,Y_test_monthly= train_test_split(X_monthly,Y_monthly,test_size=0.2,random_state=42)
print("X_train shape: ",X_train_monthly.shape)
print('X_test shape: ',X_test_monthly.shape)
print('Y_train shape: ',Y_train_monthly.shape)
print("Y_test shape:",Y_test_monthly.shape)
# Out:
# X_train shape:  (336, 7)
# X_test shape:  (84, 7)
# Y_train shape:  (336,)
# Y_test shape: (84,)

# %%
# scaling
from sklearn.preprocessing import StandardScaler

scalar= StandardScaler()
X_train_scalar_monthly= scalar.fit_transform(X_train_monthly)
X_test_scalar_monthly= scalar.transform(X_test_monthly)

# here we perform scaling for regression
#scaling makes all the features in similar range.
#if we do scaling nofeatures will dominates the model

#fit_transform() learn the data or parameters and apply it
#transform() only apply the data

# %% [markdown]
# # Building the linear regression/ridge regression

# %%
# trainning the model

linear_regression_monthly= LinearRegression()
#linear_regression_monthly= Ridge()
linear_regression_monthly.fit(X_train_scalar_monthly,Y_train_monthly)

# making the prediction in train and test

y_train_pred_monthly=linear_regression_monthly.predict(X_train_scalar_monthly)
y_test_pred_monthly=linear_regression_monthly.predict(X_test_scalar_monthly)

#y_train_pred = ...	Predict labels for training data to check learning
#y_test_pred = ...	Predict labels for unseen test data to check generalization


# Residuals
residuals = Y_test_monthly - y_test_pred_monthly

plt.figure(figsize=(7,5))
plt.scatter(y_test_pred_monthly, residuals, color='blue', alpha=0.6)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals (Actual - Predicted)")
plt.title("Residual Plot for Regression Model")
plt.show()

# %% [markdown]
# if residuals look random → model is good.<br>
# If residuals show patterns → model isn’t perfect, maybe you need a more complex

# %%
# performing the prediction and evaluation
print("At beginning")
print("R² Score:", r2_score(Y_test_monthly, y_test_pred_monthly))
print("MSE:", mean_squared_error(Y_test_monthly, y_test_pred_monthly))
print("RMSE:",np.sqrt( mean_squared_error(Y_test_monthly, y_test_pred_monthly)))
print("MAE:", mean_absolute_error(Y_test_monthly, y_test_pred_monthly))
# Out:
# At beginning
# R² Score: 0.8446598824092765
# MSE: 286069.172206059
# RMSE: 534.8543467207301
# MAE: 424.1394180326943

# %% [markdown]
# # **here we will try in another too. we will group the country on different approach make analysis which gives better**

# %% [markdown]
# Groupping accoriding to week

# %%
# monthly aggragating per country
# Aggregate  monthly averages of energy consumption per country
weekly = (
    df.groupby('country')
      .resample('W', on='date')
      .mean()
      .reset_index()
)

print(weekly.head())
print("Rows after  monthly aggregation:", weekly.shape[0])
weekly['year'] =  weekly['date'].dt.year
weekly['month'] = weekly['date'].dt.month

weekly.head(5)

# here our target value is energu consumption so we will we y as energy consumption and x as other features
X1 = weekly[['avg_temperature','humidity','co2_emission',
               'renewable_share','urban_population',
               'industrial_activity_index','energy_price']]

Y1 = weekly['energy_consumption']

# performing the train test
# performing the train test split
X_train,X_test,Y_train,Y_test= train_test_split(X1,Y1,test_size=0.2,random_state=42)
print("X_train shape: ",X_train.shape)
print('X_test shape: ',X_test.shape)
print('Y_train shape: ',Y_train.shape)
print("Y_test shape:",Y_test.shape)
# trainning the model


scalar= StandardScaler()
X_train_scalar= scalar.fit_transform(X_train)
X_test_scalar= scalar.transform(X_test)


linear_regression= LinearRegression()
linear_regression.fit(X_train_scalar,Y_train)
# making the prediction in traina and test

y_train_pred=linear_regression.predict(X_train_scalar)
y_test_pred=linear_regression.predict(X_test_scalar)

#y_train_pred = ...	Predict labels for training data to check learning
#y_test_pred = ...	Predict labels for unseen test data to check generalization

# performing the prediction and evaluation
print("At beginning")
print("R² Score:", r2_score(Y_test, y_test_pred))
print("MSE:", mean_squared_error(Y_test, y_test_pred))
print("RMSE:",np.sqrt( mean_squared_error(Y_test, y_test_pred)))
print("MAE:", mean_absolute_error(Y_test, y_test_pred))
# Out:
#      country       date  avg_temperature   humidity  co2_emission  \
# 0  Australia 2020-01-05        29.526000  56.112000    458.906000
# 1  Australia 2020-01-12        29.348571  59.751429    391.815714
# 2  Australia 2020-01-19        28.978571  60.357143    438.534286
# 3  Australia 2020-01-26        29.030000  66.641429    467.020000
# 4  Australia 2020-02-02        29.608571  53.402857    583.741429
#
#    energy_consumption  renewable_share  urban_population  \
# 0         3834.984000        11.600000         68.954000
# 1         7644.604286        12.415714         75.450000
# 2         4805.854286        12.570000         73.502857
# 3         6477.155714        10.415714         76.931429
# 4         4745.560000         9.008571         70.127143
#
#    industrial_activity_index  energy_price
# 0                  75.186000     97.050000
# 1                  67.044286     94.357143
# 2                  67.760000    155.341429
# 3                  66.098571    117.071429
# 4                  74.281429    129.517143
# Rows after  monthly aggregation: 5240
# X_train shape:  (4192, 7)
# X_test shape:  (1048, 7)
# Y_train shape:  (4192,)
# Y_test shape: (1048,)
# At beginning
# R² Score: 0.3153229120548786
# MSE: 2653710.425605195
# RMSE: 1629.0213091317114
# MAE: 1315.598910672208

# %% [markdown]
# grouping according to month

# %%
# monthly aggragating per country
# Aggregate  monthly averages of energy consumption per country
monthly = (
    df.groupby('country')
      .resample('M', on='date')
      .mean()
      .reset_index()
)

print(monthly.head())
print("Rows after  monthly aggregation:", monthly.shape[0])
monthly['year'] =  monthly['date'].dt.year
monthly['month'] = monthly['date'].dt.month

monthly.head(5)

# here our target value is energu consumption so we will we y as energy consumption and x as other features
X1 = monthly[['avg_temperature','humidity','co2_emission',
               'renewable_share','urban_population',
               'industrial_activity_index','energy_price']]

Y1 = monthly['energy_consumption']

# performing the train test
# performing the train test split
X_train,X_test,Y_train,Y_test= train_test_split(X1,Y1,test_size=0.2,random_state=42)
print("X_train shape: ",X_train.shape)
print('X_test shape: ',X_test.shape)
print('Y_train shape: ',Y_train.shape)
print("Y_test shape:",Y_test.shape)
# trainning the model


scalar= StandardScaler()
X_train_scalar= scalar.fit_transform(X_train)
X_test_scalar= scalar.transform(X_test)


linear_regression= LinearRegression()
linear_regression.fit(X_train_scalar,Y_train)
# making the prediction in traina and test

y_train_pred=linear_regression.predict(X_train_scalar)
y_test_pred=linear_regression.predict(X_test_scalar)

#y_train_pred = ...	Predict labels for training data to check learning
#y_test_pred = ...	Predict labels for unseen test data to check generalization

# performing the prediction and evaluation
print("At beginning")
print("R² Score:", r2_score(Y_test, y_test_pred))
print("MSE:", mean_squared_error(Y_test, y_test_pred))
print("RMSE:",np.sqrt( mean_squared_error(Y_test, y_test_pred)))
print("MAE:", mean_absolute_error(Y_test, y_test_pred))
# Out:
#      country       date  avg_temperature   humidity  co2_emission  \
# 0  Australia 2020-01-31        29.129032  59.520323    448.193226
# 1  Australia 2020-02-29        33.432759  53.871724    498.721379
# 2  Australia 2020-03-31        35.041290  61.756452    580.137742
# 3  Australia 2020-04-30        33.849000  56.947000    502.224667
# 4  Australia 2020-05-31        29.434516  62.062258    424.790968
#
#    energy_consumption  renewable_share  urban_population  \
# 0         5738.055484        11.165161         73.819032
# 1         7249.263103         8.852414         74.500690
# 2         8364.867419         9.231935         76.314839
# 3         8032.205333        10.108667         72.702333
# 4         7715.570968        10.449355         75.756129
#
#    industrial_activity_index  energy_price
# 0                  68.508710    119.663548
# 1                  70.835862    130.273448
# 2                  72.131935    122.321613
# 3                  71.487667    112.018667
# 4                  67.723871    117.906452
# Rows after  monthly aggregation: 1200
# X_train shape:  (960, 7)
# X_test shape:  (240, 7)
# Y_train shape:  (960,)
# Y_test shape: (240,)
# At beginning
# R² Score: 0.7193366453854072
# MSE: 742217.4780983384
# RMSE: 861.5204455486465
# MAE: 688.2159605249649
# /tmp/ipykernel_2045/3852969022.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .resample('M', on='date')

# %% [markdown]
# groupping according to 6 month

# %%
# monthly aggragating per country
# Aggregate  monthly averages of energy consumption per country
monthly = (
    df.groupby('country')
      .resample('6M', on='date')
      .mean()
      .reset_index()
)

print(monthly.head())
print("Rows after  monthly aggregation:", monthly.shape[0])
monthly['year'] =  monthly['date'].dt.year
monthly['month'] = monthly['date'].dt.month

monthly.head(5)

# here our target value is energu consumption so we will we y as energy consumption and x as other features
X1 = monthly[['avg_temperature','humidity','co2_emission',
               'renewable_share','urban_population',
               'industrial_activity_index','energy_price']]

Y1 = monthly['energy_consumption']

# performing the train test
# performing the train test split
X_train,X_test,Y_train,Y_test= train_test_split(X1,Y1,test_size=0.2,random_state=42)
print("X_train shape: ",X_train.shape)
print('X_test shape: ',X_test.shape)
print('Y_train shape: ',Y_train.shape)
print("Y_test shape:",Y_test.shape)
# trainning the model


scalar= StandardScaler()
X_train_scalar= scalar.fit_transform(X_train)
X_test_scalar= scalar.transform(X_test)


linear_regression= LinearRegression()
linear_regression.fit(X_train_scalar,Y_train)
# making the prediction in traina and test

y_train_pred=linear_regression.predict(X_train_scalar)
y_test_pred=linear_regression.predict(X_test_scalar)

#y_train_pred = ...	Predict labels for training data to check learning
#y_test_pred = ...	Predict labels for unseen test data to check generalization

# performing the prediction and evaluation
print("At beginning")
print("R² Score:", r2_score(Y_test, y_test_pred))
print("MSE:", mean_squared_error(Y_test, y_test_pred))
print("RMSE:",np.sqrt( mean_squared_error(Y_test, y_test_pred)))
print("MAE:", mean_absolute_error(Y_test, y_test_pred))
# Out:
# /tmp/ipykernel_2045/404250446.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .resample('6M', on='date')
#      country       date  avg_temperature   humidity  co2_emission  \
# 0  Australia 2020-01-31        29.129032  59.520323    448.193226
# 1  Australia 2020-07-31        28.764231  59.242967    448.239011
# 2  Australia 2021-01-31        18.282989  57.901196    459.388587
# 3  Australia 2021-07-31        28.499834  60.225414    428.038508
# 4  Australia 2022-01-31        18.468424  63.121685    431.748804
#
#    energy_consumption  renewable_share  urban_population  \
# 0         5738.055484        11.165161         73.819032
# 1         6996.982473         9.989945         74.593901
# 2         7145.511685        10.411304         76.024783
# 3         7143.931492        13.290663         74.420608
# 4         7166.565761        13.305000         75.131033
#
#    industrial_activity_index  energy_price
# 0                  68.508710    119.663548
# 1                  71.070165    118.481044
# 2                  68.420652    118.804130
# 3                  68.848398    113.372265
# 4                  68.990435    110.161304
# Rows after  monthly aggregation: 220
# X_train shape:  (176, 7)
# X_test shape:  (44, 7)
# Y_train shape:  (176,)
# Y_test shape: (44,)
# At beginning
# R² Score: 0.23250149037664913
# MSE: 88212.63266303933
# RMSE: 297.0061155313798
# MAE: 256.1150820626353

# %% [markdown]
# according to quartly

# %%
quarterly_df = (
    df.groupby('country')
      .resample('Q', on='date')   # 3-month grouping
      .mean()
      .reset_index()
)

quarterly_df['year'] = quarterly_df['date'].dt.year
quarterly_df['quarter'] = quarterly_df['date'].dt.quarter

print(quarterly_df.head())
print("Rows after 3-month aggregation:", quarterly_df.shape[0])

# quartely aggragating per country


print(quarterly_df.head())
print("Rows after  quarterly_df aggregation:", quarterly_df.shape[0])
quarterly_df['year'] =  quarterly_df['date'].dt.year
quarterly_df['month'] = quarterly_df['date'].dt.month

quarterly_df.head(5)

# here our target value is energu consumption so we will we y as energy consumption and x as other features
X1 = quarterly_df[['avg_temperature','humidity','co2_emission',
               'renewable_share','urban_population',
               'industrial_activity_index','energy_price']]

Y1 = quarterly_df['energy_consumption']

# performing the train test
# performing the train test split
X_train,X_test,Y_train,Y_test= train_test_split(X1,Y1,test_size=0.2,random_state=42)
print("X_train shape: ",X_train.shape)
print('X_test shape: ',X_test.shape)
print('Y_train shape: ',Y_train.shape)
print("Y_test shape:",Y_test.shape)
# trainning the model


scalar= StandardScaler()
X_train_scalar= scalar.fit_transform(X_train)
X_test_scalar= scalar.transform(X_test)


linear_regression= LinearRegression()
linear_regression.fit(X_train_scalar,Y_train)
# making the prediction in traina and test

y_train_pred=linear_regression.predict(X_train_scalar)
y_test_pred=linear_regression.predict(X_test_scalar)

#y_train_pred = ...	Predict labels for training data to check learning
#y_test_pred = ...	Predict labels for unseen test data to check generalization

# performing the prediction and evaluation
print("At beginning")
print("R² Score:", r2_score(Y_test, y_test_pred))
print("MSE:", mean_squared_error(Y_test, y_test_pred))
print("RMSE:",np.sqrt( mean_squared_error(Y_test, y_test_pred)))
print("MAE:", mean_absolute_error(Y_test, y_test_pred))
# Out:
#      country       date  avg_temperature   humidity  co2_emission  \
# 0  Australia 2020-03-31        32.514615  58.481978    509.243736
# 1  Australia 2020-06-30        28.920220  59.797253    389.484396
# 2  Australia 2020-09-30        14.386630  57.209674    528.583804
# 3  Australia 2020-12-31        18.285435  59.410870    393.158261
# 4  Australia 2021-03-31        32.345778  59.532556    491.380111
#
#    energy_consumption  renewable_share  urban_population  \
# 0         7114.497143         9.769560         74.886484
# 1         6714.492527        10.257473         74.363956
# 2         7925.256739        10.554239         74.927609
# 3         6399.888804         9.718913         76.949348
# 4         7921.747889        12.703000         74.652778
#
#    industrial_activity_index  energy_price  year  quarter
# 0                  70.484615    123.950220  2020        1
# 1                  69.628132    116.592747  2020        2
# 2                  69.969348    116.178370  2020        3
# 3                  68.566848    117.498152  2020        4
# 4                  68.877222    120.215667  2021        1
# Rows after 3-month aggregation: 400
#      country       date  avg_temperature   humidity  co2_emission  \
# 0  Australia 2020-03-31        32.514615  58.481978    509.243736
# 1  Australia 2020-06-30        28.920220  59.797253    389.484396
# 2  Australia 2020-09-30        14.386630  57.209674    528.583804
# 3  Australia 2020-12-31        18.285435  59.410870    393.158261
# 4  Australia 2021-03-31        32.345778  59.532556    491.380111
#
#    energy_consumption  renewable_share  urban_population  \
# 0         7114.497143         9.769560         74.886484
# 1         6714.492527        10.257473         74.363956
# 2         7925.256739        10.554239         74.927609
# 3         6399.888804         9.718913         76.949348
# 4         7921.747889        12.703000         74.652778
#
#    industrial_activity_index  energy_price  year  quarter
# 0                  70.484615    123.950220  2020        1
# 1                  69.628132    116.592747  2020        2
# 2                  69.969348    116.178370  2020        3
# 3                  68.566848    117.498152  2020        4
# 4                  68.877222    120.215667  2021        1
# Rows after  quarterly_df aggregation: 400
# X_train shape:  (320, 7)
# X_test shape:  (80, 7)
# Y_train shape:  (320,)
# Y_test shape: (80,)
# At beginning
# R² Score: 0.6272973053311335
# MSE: 290820.02630451706
# RMSE: 539.2773185518904
# MAE: 437.57114213724054
# /tmp/ipykernel_2045/339224585.py:3: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   .resample('Q', on='date')   # 3-month grouping

# %%
# monthly aggragating per country
# Aggregate  monthly averages of energy consumption per country
monthly = (
    df.groupby('country')
      .resample('12M', on='date')
      .mean()
      .reset_index()
)

print(monthly.head())
print("Rows after  monthly aggregation:", monthly.shape[0])
monthly['year'] =  monthly['date'].dt.year
monthly['month'] = monthly['date'].dt.month

monthly.head(5)

# here our target value is energu consumption so we will we y as energy consumption and x as other features
X1 = monthly[['avg_temperature','humidity','co2_emission',
               'renewable_share','urban_population',
               'industrial_activity_index','energy_price']]

Y1 = monthly['energy_consumption']

# performing the train test
# performing the train test split
X_train,X_test,Y_train,Y_test= train_test_split(X1,Y1,test_size=0.2,random_state=42)
print("X_train shape: ",X_train.shape)
print('X_test shape: ',X_test.shape)
print('Y_train shape: ',Y_train.shape)
print("Y_test shape:",Y_test.shape)
# trainning the model


scalar= StandardScaler()
X_train_scalar= scalar.fit_transform(X_train)
X_test_scalar= scalar.transform(X_test)


linear_regression= LinearRegression()
linear_regression.fit(X_train_scalar,Y_train)
# making the prediction in traina and test

y_train_pred=linear_regression.predict(X_train_scalar)
y_test_pred=linear_regression.predict(X_test_scalar)

#y_train_pred = ...	Predict labels for training data to check learning
#y_test_pred = ...	Predict labels for unseen test data to check generalization

# performing the prediction and evaluation
print("At beginning")
print("R² Score:", r2_score(Y_test, y_test_pred))
print("MSE:", mean_squared_error(Y_test, y_test_pred))
print("RMSE:",np.sqrt( mean_squared_error(Y_test, y_test_pred)))
print("MAE:", mean_absolute_error(Y_test, y_test_pred))
# Out:
#      country       date  avg_temperature   humidity  co2_emission  \
# 0  Australia 2020-01-31        29.129032  59.520323    448.193226
# 1  Australia 2021-01-31        23.494973  58.568415    453.844262
# 2  Australia 2022-01-31        23.442904  61.685452    429.908904
# 3  Australia 2023-01-31        23.278986  59.523616    459.300822
# 4  Australia 2024-01-31        23.283534  60.499589    466.912137
#
#    energy_consumption  renewable_share  urban_population  \
# 0         5738.055484        11.165161         73.819032
# 1         7071.652896        10.201776         75.313251
# 2         7155.341644        13.297890         74.778740
# 3         7261.438548        15.983425         75.208767
# 4         7630.444630        19.186110         75.465671
#
#    industrial_activity_index  energy_price
# 0                  68.508710    119.663548
# 1                  69.738169    118.643470
# 2                  68.920000    111.753589
# 3                  72.105863    113.017205
# 4                  71.452164    110.244027
# Rows after  monthly aggregation: 120
# X_train shape:  (96, 7)
# X_test shape:  (24, 7)
# Y_train shape:  (96,)
# Y_test shape: (24,)
# At beginning
# R² Score: 0.21252650497001457
# MSE: 111097.34188894334
# RMSE: 333.31267886017076
# MAE: 241.57859178861113
# /tmp/ipykernel_2045/3524372440.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   .resample('12M', on='date')

# %% [markdown]
# i have tried on all the possible data like daily,weekly, monthly,quartely,yearly.<br>
# i test on the all the possible groupping and i founf this result<br>
# _______________________________________________________________________________________<br>
# for week <br>
# At beginning<br>
# R² Score: 0.3153229120548786<br>
# MSE: 2653710.425605195<br>
# RMSE: 1629.0213091317114<br>
# MAE: 1315.598910672208<br>
# _______________________________________________________________________________________<br>
# according to 1 monthly<br>
# At beginning<br>
# R² Score: 0.7193366453854072<br>
# MSE: 742217.4780983384<br>
# RMSE: 861.5204455486465<br>
# MAE: 688.2159605249649<br>
# _______________________________________________________________________________________<br>
# According t0 3 month <br>
# At beginning<br>
# R² Score: 0.8446598824092765<br>
# MSE: 286069.172206059<br>
# RMSE: 534.8543467207301<br>
# MAE: 424.1394180326943<br>
#
# _______________________________________________________________________________________<br>
# According to quartly <br>
#
# At beginning<br>
# R² Score: 0.6272973053311335<br>
# MSE: 290820.02630451706<br>
# RMSE: 539.2773185518904<br>
# MAE: 437.57114213724054<br>
#
# _______________________________________________________________________________________<br>
# According to yearly<br>
# R² Score: 0.21252650497001457
# MSE: 111097.34188894334
# RMSE: 333.31267886017076
# MAE: 241.57859178861113
#
# _______________________________________________________________________________________<br>
#
# but i found the best result from 3 month groupping as R² Score: 0.8446598824092765<br>
# MSE: 286069.172206059<br>
# RMSE: 534.8543467207301<br>
# MAE: 424.1394180326943<br>
# so i will use monthly_df as my dataframe

# %% [markdown]
# # Hyper parameter tunning using ridge

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import GridSearchCV

# ridge means r2, it adds penalty to our loss function to avoid overfitting
ridge= Ridge(random_state=42)
param_grid= {
    'alpha':[0.001,0.01,1,10,100,1000]
}
print("alpha values are ",param_grid['alpha'])
# Out:
# alpha values are  [0.001, 0.01, 1, 10, 100, 1000]

# %%
ridge_grid_search= GridSearchCV(
    estimator=ridge,
    param_grid=param_grid,
    cv= 5,
  scoring='r2',
    n_jobs=-1,
    verbose=1
)
ridge_grid_search.fit(X_train_scalar_monthly, Y_train_monthly)
print("Best Ridge alpha:", ridge_grid_search.best_params_)
print("Best Ridge MSE:", ridge_grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best Ridge alpha: {'alpha': 1}
# Best Ridge MSE: 0.8513191587999585

# %%
# Get the best parameters
best_ridge_alpha = ridge_grid_search.best_params_['alpha']
print(f"Best alpha for Ridge: {best_ridge_alpha}")

# Get cross-validation results
ridge_cv_results = pd.DataFrame(ridge_grid_search.cv_results_)
ridge_cv_results['mean_mse'] = ridge_cv_results['mean_test_score']
ridge_cv_results['std_mse'] = ridge_cv_results['std_test_score']

print("\nCross-Validation Results for Ridge:")
print(ridge_cv_results[['param_alpha', 'mean_mse', 'std_mse']].to_string(index=False))
# Out:
# Best alpha for Ridge: 1
#
# Cross-Validation Results for Ridge:
#  param_alpha  mean_mse  std_mse
#        0.001  0.851297 0.030462
#        0.010  0.851297 0.030462
#        1.000  0.851319 0.030426
#       10.000  0.850440 0.030148
#      100.000  0.787067 0.028724
#     1000.000  0.306431 0.016279

# %%
# now rebuilding the model after tunning hyper parameter
#finds the best model
best_ridge= ridge_grid_search.best_estimator_
# predictig for testing and traiinning

y_train_pred = best_ridge.predict(X_train_scalar_monthly)
y_test_pred = best_ridge.predict(X_test_scalar_monthly)


# performance on testing
print("after tunning hyper parameter")
print("R² Score:", r2_score(Y_test_monthly, y_test_pred))
print("MSE:", mean_squared_error(Y_test_monthly, y_test_pred))
print("RMSE:",np.sqrt( mean_squared_error(Y_test_monthly, y_test_pred)))
print("MAE:", mean_absolute_error(Y_test_monthly, y_test_pred))
# Out:
# after tunning hyper parameter
# R² Score: 0.8445417642553598
# MSE: 286286.69465317397
# RMSE: 535.0576554476853
# MAE: 424.51704523465986

# %% [markdown]
# using ridge: after tunning hyper parameter<br>
# R² Score: 0.8445417642553598<br>
# MSE: 286286.69465317397<br>
# RMSE: 535.0576554476853<br>
# MAE: 424.51704523465986<br>

# %% [markdown]
# # Feature selecton usinf RFE method

# %%
from sklearn.feature_selection import RFE

# Step 1: Define RFE with tuned linear regression
rfe_linearRegression = RFE(estimator=best_ridge, n_features_to_select=5)

# Step 2: Transform both train and test sets
X_train_selected_ridge = rfe_linearRegression.fit_transform(X_train_scalar_monthly,Y_train_monthly)
X_test_selected_ridge = rfe_linearRegression.transform(X_test_scalar_monthly)

print("Selected Features :", rfe_linearRegression.support_)
print("Feature Ranking :", rfe_linearRegression.ranking_)
# Out:
# Selected Features : [ True  True  True False  True  True False]
# Feature Ranking : [1 1 1 2 1 1 3]

# %%
#plotting the ranking of the features
feature_names = X_monthly.columns
# it rank the importance
ranks = rfe_linearRegression.ranking_


feature_ranks = pd.DataFrame({
    'Feature': feature_names,
    'Rank': ranks
})

# Sort by importance
feature_ranks = feature_ranks.sort_values(by='Rank')
plt.figure(figsize=(8, 5))
plt.bar(feature_ranks['Feature'], feature_ranks['Rank'])
plt.xticks(rotation=45)
plt.xlabel("Features")
plt.ylabel("RFE Rank ")
plt.title("Feature Ranking using RFE")
plt.show()

# %% [markdown]
# above figure shows the top 5 selected features among 7 features. avg_temperature,humidity,c02_emission,urban_population,indrustrial_activity_inde were selected as important features and renewable_share,energy_price were excluded.

# %% [markdown]
# **Finally re train the model with optimzed hyperparameter and feature selection**

# %%
# retrainning the model
# final_model = LinearRegression()
# find all the best parameetrs from hyperparameter
final_model = Ridge(**ridge_grid_search.best_params_, random_state=42)

#Retrain on selected features (from RFE)
final_model.fit(X_train_selected_ridge, Y_train_monthly)

# Predict on test set
y_pred_rfe = final_model.predict(X_test_selected_ridge)

# Step 4: Evaluate performance
print("Ridge Regression after RFE Feature Selection:")
print("R² Score:", r2_score(Y_test_monthly, y_pred_rfe))
print("MSE:", mean_squared_error(Y_test_monthly, y_pred_rfe))
print("RMSE:", np.sqrt(mean_squared_error(Y_test_monthly, y_pred_rfe)))
print("MAE:", mean_absolute_error(Y_test_monthly, y_pred_rfe))
# Out:
# Ridge Regression after RFE Feature Selection:
# R² Score: 0.8436325673248638
# MSE: 287961.04135326174
# RMSE: 536.6200157963377
# MAE: 426.5475310834916

# %% [markdown]
# # **Model 2**

# %% [markdown]
# # Building random forest regressor

# %% [markdown]
# import all the necessary files

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
rf_regressor= RandomForestRegressor(random_state=42)
# trainnig on test and train data
rf_regressor.fit(X_train_scalar_monthly,Y_train_monthly)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# - Bagging = Bootstrap + Aggregation
# - Bootstrap sampling → each tree is trained on a random sample of the dataset (with replacement).
#
# - Aggregation → combine predictions:
# - regression → mean.

# %%
# predict the result on both trainnig and testing
Y_train_prediction= rf_regressor.predict(X_train_scalar_monthly)
Y_test_prediction= rf_regressor.predict(X_test_scalar_monthly)

# %% [markdown]
# Evaluating the data performance

# %%
print("Base line for rando forest regressor")
print("R2 score",r2_score(Y_test_monthly,Y_test_prediction))
print("MSE:", mean_squared_error(Y_test_monthly, Y_test_prediction))
print("RMSE:", np.sqrt(mean_squared_error(Y_test_monthly, Y_test_prediction)))
print("MAE:", mean_absolute_error(Y_test_monthly, Y_test_prediction))
# Out:
# Base line for rando forest regressor
# R2 score 0.8915759834462154
# MSE: 199670.0475309118
# RMSE: 446.84454515067296
# MAE: 337.76123982901726

# %% [markdown]
# here its baseline output is <br>
# Base line for random forest regressor<br>
# R2 score 0.8915759834462154<br>
# MSE: 199670.0475309118<br>
# RMSE:  446.84454515067296<br>
# MAE: 337.76123982901726<br>
# its output is too way good than linear regression becuase linear regression assune a straight line relationship between feature and target. our dataset has slighlty non linear so i cant catch too good than random forest. but random forest take the average of probability od each tree and it reduce overfitting so it perform good

# %% [markdown]
# # **Hyperparameter tunning **

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={
        # n estimators means number of decision tree
    'n_estimators': [100, 200,300],

    #Maximum number of splits from root to leaf. how long does tree can grow
    'max_depth': [5, 10,15],


    # Minimum samples required to split an internal node
    'min_samples_split': [2, 5,10],
}
#model posible= 3*3*3= 27
#if we do cv=5 then 27*5= 135 models

# %%
grid_search=GridSearchCV(
    estimator=rf_regressor,
    param_grid=param_grid,
    cv=5,
    n_jobs=-1,
    scoring='r2'
)

# %%
# fitting the data
grid_search.fit(X_train_scalar_monthly,Y_train_monthly)
#best input
print("Best Parameters:", grid_search.best_params_)
print("Best CV R² Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 200}
# Best CV R² Score: 0.8930950064485229

# %%
# now rebuilding the model after tunning hyper parameter
#finds the best model
best_model= grid_search.best_estimator_
# predictig for testing and traiinning

y_train_pred_regressor = best_model.predict(X_train_scalar_monthly)
y_test_pred_regressor = best_model.predict(X_test_scalar_monthly)


# performance on testing
print("after tunning hyper parameter")
print("R² Score:", r2_score(Y_test_monthly, y_test_pred_regressor))
print("MSE:", mean_squared_error(Y_test_monthly, y_test_pred_regressor))
print("RMSE:",np.sqrt( mean_squared_error(Y_test_monthly, y_test_pred_regressor)))
print("MAE:", mean_absolute_error(Y_test_monthly, y_test_pred_regressor))
# Out:
# after tunning hyper parameter
# R² Score: 0.8934028732506123
# MSE: 196305.7082851256
# RMSE: 443.0640002134292
# MAE: 332.2650521467257

# %% [markdown]
# feature selection using RFE

# %%
rfe_random_forest= RFE(estimator=best_model, n_features_to_select=5)

# fit the model on trainning and testing
X_train_selected_rf= rfe_random_forest.fit_transform(X_train_scalar_monthly,Y_train_monthly)
X_test_selected_rf= rfe_random_forest.transform(X_test_scalar_monthly)

print("Selected Features:", rfe_random_forest.support_)   # Boolean mask of selected features
print("Feature Ranking:", rfe_random_forest.ranking_)
# Out:
# Selected Features: [ True False  True  True False  True  True]
# Feature Ranking: [1 3 1 1 2 1 1]

# %%
#plotting the ranking of the features
feature_names = X_monthly.columns
ranks = rfe_random_forest.ranking_


feature_ranks = pd.DataFrame({
    'Feature': feature_names,
    'Rank': ranks
})

# Sort by importance
feature_ranks = feature_ranks.sort_values(by='Rank')
plt.figure(figsize=(8, 5))
plt.bar(feature_ranks['Feature'], feature_ranks['Rank'])
plt.xticks(rotation=45)
plt.xlabel("Features")
plt.ylabel("RFE Rank ")
plt.title("Feature Ranking using RFE")
plt.show()

# %%
# now building the final model with tuned hyper parameter and selected featurs
#get all the best parameters from grid search
final_rf_model= RandomForestRegressor(**grid_search.best_params_, random_state=42)
# retrainning the model on selected rfe
final_rf_model.fit(X_train_selected_rf,Y_train_monthly)
# doing prediction
Y_final_pred= final_rf_model.predict(X_test_selected_rf)

print("Random Forest Regressor after RFE Feature Selection:")
print("R² Score:", r2_score(Y_test_monthly, Y_final_pred))
print("MSE:", mean_squared_error(Y_test_monthly, Y_final_pred))
print("RMSE:", np.sqrt(mean_squared_error(Y_test_monthly, Y_final_pred)))
print("MAE:", mean_absolute_error(Y_test_monthly, Y_final_pred))
# Out:
# Random Forest Regressor after RFE Feature Selection:
# R² Score: 0.8925006039601852
# MSE: 197967.2972746453
# RMSE: 444.93516075339033
# MAE: 337.6092463996401

# %%
# Collect results from your evaluations
results = {
    "Model": ["Ridge Regression", "Random Forest Regressor"],
    "Features Used": [X_train_selected_rf.shape[1], X_train_selected_rf.shape[1]],  # both used 5 features
    "CV Score": [ridge_grid_search.best_score_, grid_search.best_score_],
    "Test RMSE": [
        np.sqrt(mean_squared_error(Y_test_monthly, y_pred_rfe)),
        np.sqrt(mean_squared_error(Y_test_monthly, Y_final_pred))
    ],
    "Test R²": [
        r2_score(Y_test_monthly, y_pred_rfe),
        r2_score(Y_test_monthly, Y_final_pred)
    ],
    "MAE": [
        mean_absolute_error(Y_test_monthly, y_pred_rfe),
        mean_absolute_error(Y_test_monthly, Y_final_pred)
    ],
    "MSE":[
        mean_squared_error(Y_test_monthly, y_pred_rfe),
        mean_squared_error(Y_test_monthly, Y_final_pred)
    ]
}

# Create DataFrame
comparison_df = pd.DataFrame(results)

print(comparison_df)
# Out:
#                      Model  Features Used  CV Score   Test RMSE   Test R²  \
# 0         Ridge Regression              5  0.851319  536.620016  0.843633
# 1  Random Forest Regressor              5  0.893095  444.935161  0.892501
#
#           MAE            MSE
# 0  426.547531  287961.041353
# 1  337.609246  197967.297275

# %% [markdown]
# “RMSE and MAE are error metrics expressed in the same units as the target variable. Since our target values are very large, the errors also look large numerically. But when compared to the scale of energy consumption, these errors are actually very small — less than 1% of the target values. That’s why R² is a better indicator of performance here, and it shows our models explain most of the variance. Random Forest achieved lower RMSE and MAE than Ridge, confirming its stronger predictive ability. our model is predicting with a gap of 536 for ridge and 444 for random forest

# %% [markdown]
# # **Building Neural Model**

# %%
# performing the scaling
scaler_reg = StandardScaler()
X_train_reg_scaled = scaler_reg.fit_transform(X_train_monthly)
X_test_reg_scaled = scaler_reg.transform(X_test_monthly)

# %% [markdown]
# Creating the mlp regressor

# %%
from sklearn.neural_network import MLPRegressor
mlp_reg= MLPRegressor(

   hidden_layer_sizes=(1000,500),      # Two hidden layers
   #for first layer if we have 7 parameter then 7*1000+1000=8000
   #for secod layer gets 1000 output from first layer so 1000*500+500= 500000+500=500500
   #for output= 500*1+1= 501
   #sum= 8000+500500+501=
    activation='relu',                # ReLU activation
  #  it is used in backward propagation to optimize the weight inorder to minimize the loss

   #- It decides how gradient descent is performed to minimize the loss function.
    solver='adam',                    # Adam optimizer
    alpha=0.001,                     # L2 regularization
    learning_rate='constant',
    learning_rate_init=0.001,
    max_iter=2000,                     # Increased for demonstration
    early_stopping=True,              # Stop when validation score doesn't improve
    validation_fraction=0.1,          # 10% of training for validation
    n_iter_no_change=20,              # Stop after 20 iterations with no improvement
    random_state=42,
    verbose=True                      # Show training progress
)

# %%
# train the regressor
mlp_reg.fit(X_train_reg_scaled ,Y_train_monthly)
# Out:
# Iteration 1, loss = 27070377.66653842
# Validation score: -23.193361
# Iteration 2, loss = 27059322.47606485
# Validation score: -23.182421
# Iteration 3, loss = 27047435.58845141
# Validation score: -23.169894
# Iteration 4, loss = 27033767.27378488
# Validation score: -23.155330
# Iteration 5, loss = 27017946.52357847
# Validation score: -23.138476
# Iteration 6, loss = 26999405.83426826
# Validation score: -23.119073
# Iteration 7, loss = 26978200.53055830
# Validation score: -23.096866
# Iteration 8, loss = 26953686.94855396
# Validation score: -23.071511
# Iteration 9, loss = 26925965.78523707
# Validation score: -23.042616
# Iteration 10, loss = 26894219.58603803
# Validation score: -23.009794
# Iteration 11, loss = 26858143.27806921
# Validation score: -22.972654
# Iteration 12, loss = 26816614.19741445
# Validation score: -22.930785
# Iteration 13, loss = 26770548.43771715
# Validation score: -22.883659
# Iteration 14, loss = 26718094.50632879
# Validation score: -22.830718
# Iteration 15, loss = 26659318.88296993
# Validation score: -22.771540
# Iteration 16, loss = 26593837.98359334
# Validation score: -22.705468
# Iteration 17, loss = 26520814.47615781
# Validation score: -22.632001
# Iteration 18, loss = 26438876.70285523
# Validation score: -22.550591
# Iteration 19, loss = 26348029.26070107
# Validation score: -22.460562
# Iteration 20, loss = 26248553.73536938
# Validation score: -22.361404
# Iteration 21, loss = 26137412.87002844
# Validation score: -22.252414
# Iteration 22, loss = 26015723.15151135
# Validation score: -22.132838
# Iteration 23, loss = 25883151.35377351
# Validation score: -22.002016
# Iteration 24, loss = 25736695.77033025
# Validation score: -21.859559
# Iteration 25, loss = 25578500.04426033
# Validation score: -21.704646
# Iteration 26, loss = 25403437.28248774
# Validation score: -21.536734
# Iteration 27, loss = 25215893.16534095
# Validation score: -21.355104
# Iteration 28, loss = 25014142.35843707
# Validation score: -21.159014
# Iteration 29, loss = 24793102.21913885
# Validation score: -20.948371
# Iteration 30, loss = 24557459.36659148
# Validation score: -20.721996
# Iteration 31, loss = 24300152.83011848
# Validation score: -20.479413
# Iteration 32, loss = 24030264.21377681
# Validation score: -20.219803
# Iteration 33, loss = 23738874.96004648
# Validation score: -19.943288
# Iteration 34, loss = 23427728.73468139
# Validation score: -19.649515
# Iteration 35, loss = 23098413.38845054
# Validation score: -19.337918
# Iteration 36, loss = 22745931.56818235
# Validation score: -19.008337
# Iteration 37, loss = 22380021.67661072
# Validation score: -18.660546
# Iteration 38, loss = 21988140.40259111
# Validation score: -18.294391
# Iteration 39, loss = 21573145.71062984
# Validation score: -17.909771
# Iteration 40, loss = 21136854.41879968
# Validation score: -17.506294
# Iteration 41, loss = 20691681.04650662
# Validation score: -17.083850
# Iteration 42, loss = 20214733.04068830
# Validation score: -16.643830
# Iteration 43, loss = 19715720.42782908
# Validation score: -16.186414
# Iteration 44, loss = 19199240.53711491
# Validation score: -15.711835
# Iteration 45, loss = 18669115.80744686
# Validation score: -15.220131
# Iteration 46, loss = 18112277.16200293
# Validation score: -14.712535
# Iteration 47, loss = 17540118.40053219
# Validation score: -14.189504
# Iteration 48, loss = 16956782.44325104
# Validation score: -13.652163
# Iteration 49, loss = 16345984.82392417
# Validation score: -13.102779
# Iteration 50, loss = 15729584.69317736
# Validation score: -12.541731
# Iteration 51, loss = 15098758.36579240
# Validation score: -11.971674
# Iteration 52, loss = 14457477.49390228
# Validation score: -11.393505
# Iteration 53, loss = 13796774.08446530
# Validation score: -10.809175
# Iteration 54, loss = 13145502.50216973
# Validation score: -10.219550
# Iteration 55, loss = 12488315.69790749
# Validation score: -9.627452
# Iteration 56, loss = 11804184.93390715
# Validation score: -9.036062
# Iteration 57, loss = 11148049.53715198
# Validation score: -8.445284
# Iteration 58, loss = 10480523.87145709
# Validation score: -7.859520
# Iteration 59, loss = 9817108.87387175
# Validation score: -7.279624
# Iteration 60, loss = 9166612.13633330
# Validation score: -6.708786
# Iteration 61, loss = 8522272.50509804
# Validation score: -6.150339
# Iteration 62, loss = 7887514.59199363
# Validation score: -5.605761
# Iteration 63, loss = 7276180.62459167
# Validation score: -5.076956
# Iteration 64, loss = 6685995.52559813
# Validation score: -4.567312
# Iteration 65, loss = 6110384.08238831
# Validation score: -4.080229
# Iteration 66, loss = 5564542.08556191
# Validation score: -3.617102
# Iteration 67, loss = 5033389.41695442
# Validation score: -3.180068
# Iteration 68, loss = 4545610.02194160
# Validation score: -2.769445
# Iteration 69, loss = 4082351.63675463
# Validation score: -2.388273
# Iteration 70, loss = 3654376.89742574
# Validation score: -2.036839
# Iteration 71, loss = 3260431.17863433
# Validation score: -1.716953
# Iteration 72, loss = 2892035.28996574
# Validation score: -1.428455
# Iteration 73, loss = 2571616.43658940
# Validation score: -1.170608
# Iteration 74, loss = 2276376.53985229
# Validation score: -0.943835
# Iteration 75, loss = 2016037.63630860
# Validation score: -0.746419
# Iteration 76, loss = 1792800.61071588
# Validation score: -0.576421
# Iteration 77, loss = 1598348.70233495
# Validation score: -0.433174
# Iteration 78, loss = 1430757.88205904
# Validation score: -0.314478
# Iteration 79, loss = 1294184.80046827
# Validation score: -0.218039
# Iteration 80, loss = 1179820.31253971
# Validation score: -0.141632
# Iteration 81, loss = 1086294.46867318
# Validation score: -0.082265
# Iteration 82, loss = 1012814.24169277
# Validation score: -0.037465
# Iteration 83, loss = 956469.36669459
# Validation score: -0.004650
# Iteration 84, loss = 908882.62210896
# Validation score: 0.018400
# Iteration 85, loss = 875215.69489131
# Validation score: 0.034445
# Iteration 86, loss = 849166.46845266
# Validation score: 0.044722
# Iteration 87, loss = 830618.99153696
# Validation score: 0.051064
# Iteration 88, loss = 816979.43575937
# Validation score: 0.054095
# Iteration 89, loss = 805283.85511721
# Validation score: 0.055343
# Iteration 90, loss = 796039.17521229
# Validation score: 0.055648
# Iteration 91, loss = 788106.75681349
# Validation score: 0.055807
# Iteration 92, loss = 783103.25273960
# Validation score: 0.055706
# Iteration 93, loss = 776710.48415163
# Validation score: 0.055825
# Iteration 94, loss = 770958.91569803
# Validation score: 0.056465
# Iteration 95, loss = 765180.64263312
# Validation score: 0.057967
# Iteration 96, loss = 759793.25259817
# Validation score: 0.060091
# Iteration 97, loss = 754134.94583165
# Validation score: 0.063076
# Iteration 98, loss = 747896.38483291
# Validation score: 0.066198
# Iteration 99, loss = 742319.70261139
# Validation score: 0.069627
# Iteration 100, loss = 737390.63334061
# Validation score: 0.073531
# Iteration 101, loss = 732203.64566195
# Validation score: 0.077358
# Iteration 102, loss = 726209.07574907
# Validation score: 0.080879
# Iteration 103, loss = 722136.86531959
# Validation score: 0.084823
# Iteration 104, loss = 716334.77139999
# Validation score: 0.088966
# Iteration 105, loss = 711442.42018261
# Validation score: 0.093128
# Iteration 106, loss = 707515.15507372
# Validation score: 0.097109
# Iteration 107, loss = 702932.76113619
# Validation score: 0.101032
# Iteration 108, loss = 698337.46238120
# Validation score: 0.105370
# Iteration 109, loss = 694039.90324615
# Validation score: 0.109962
# Iteration 110, loss = 689727.86363607
# Validation score: 0.114555
# Iteration 111, loss = 685453.37765597
# Validation score: 0.118852
# Iteration 112, loss = 681703.06816850
# Validation score: 0.122981
# Iteration 113, loss = 677827.08908921
# Validation score: 0.127208
# Iteration 114, loss = 673898.01076441
# Validation score: 0.131045
# Iteration 115, loss = 670006.27377540
# Validation score: 0.134669
# Iteration 116, loss = 666165.88715624
# Validation score: 0.138111
# Iteration 117, loss = 662242.02200610
# Validation score: 0.141435
# Iteration 118, loss = 658964.06623453
# Validation score: 0.144755
# Iteration 119, loss = 655045.17203635
# Validation score: 0.148097
# Iteration 120, loss = 651223.16993174
# Validation score: 0.151234
# Iteration 121, loss = 647706.77972291
# Validation score: 0.154250
# Iteration 122, loss = 644220.53150875
# Validation score: 0.157674
# Iteration 123, loss = 640641.89062866
# Validation score: 0.160905
# Iteration 124, loss = 637142.61237810
# Validation score: 0.164620
# Iteration 125, loss = 633704.99374935
# Validation score: 0.168582
# Iteration 126, loss = 630342.86403583
# Validation score: 0.172737
# Iteration 127, loss = 626883.44111356
# Validation score: 0.176276
# Iteration 128, loss = 623349.23867753
# Validation score: 0.179607
# Iteration 129, loss = 620227.40203447
# Validation score: 0.182700
# Iteration 130, loss = 616886.79393422
# Validation score: 0.186159
# Iteration 131, loss = 613671.87717377
# Validation score: 0.189493
# Iteration 132, loss = 610588.35275586
# Validation score: 0.193304
# Iteration 133, loss = 607084.04371457
# Validation score: 0.196994
# Iteration 134, loss = 604093.94286196
# Validation score: 0.200861
# Iteration 135, loss = 601068.99905832
# Validation score: 0.204621
# Iteration 136, loss = 597963.75070344
# Validation score: 0.208299
# Iteration 137, loss = 594848.46057419
# Validation score: 0.211628
# Iteration 138, loss = 591864.95147699
# Validation score: 0.214802
# Iteration 139, loss = 588882.23422334
# Validation score: 0.217975
# Iteration 140, loss = 585922.02308718
# Validation score: 0.220721
# Iteration 141, loss = 582901.53495000
# Validation score: 0.223603
# Iteration 142, loss = 580058.74082969
# Validation score: 0.226349
# Iteration 143, loss = 577205.75913968
# Validation score: 0.229143
# Iteration 144, loss = 574222.82493767
# Validation score: 0.232101
# Iteration 145, loss = 571442.75434606
# Validation score: 0.234983
# Iteration 146, loss = 568695.72109837
# Validation score: 0.237795
# Iteration 147, loss = 565807.35335365
# Validation score: 0.240428
# Iteration 148, loss = 562988.34972798
# Validation score: 0.242597
# Iteration 149, loss = 560208.55753926
# Validation score: 0.245028
# Iteration 150, loss = 557694.06121515
# Validation score: 0.247156
# Iteration 151, loss = 554802.48098534
# Validation score: 0.249610
# Iteration 152, loss = 552247.03529555
# Validation score: 0.252194
# Iteration 153, loss = 549381.77517422
# Validation score: 0.254706
# Iteration 154, loss = 546906.95152297
# Validation score: 0.257149
# Iteration 155, loss = 544251.40495682
# Validation score: 0.259516
# Iteration 156, loss = 541453.57495390
# Validation score: 0.262167
# Iteration 157, loss = 539009.26219975
# Validation score: 0.264336
# Iteration 158, loss = 536217.95031613
# Validation score: 0.266748
# Iteration 159, loss = 533509.87244284
# Validation score: 0.268788
# Iteration 160, loss = 531017.12459558
# Validation score: 0.270511
# Iteration 161, loss = 528472.06644068
# Validation score: 0.272303
# Iteration 162, loss = 525842.43696107
# Validation score: 0.274068
# Iteration 163, loss = 523299.20232026
# Validation score: 0.275942
# Iteration 164, loss = 520761.65656299
# Validation score: 0.278129
# Iteration 165, loss = 518358.08970693
# Validation score: 0.280116
# Iteration 166, loss = 515783.21509460
# Validation score: 0.282492
# Iteration 167, loss = 513477.04363776
# Validation score: 0.284593
# Iteration 168, loss = 510919.57930279
# Validation score: 0.286588
# Iteration 169, loss = 508535.79873006
# Validation score: 0.288971
# Iteration 170, loss = 506026.78109138
# Validation score: 0.291430
# Iteration 171, loss = 503687.36890478
# Validation score: 0.294001
# Iteration 172, loss = 501354.78500765
# Validation score: 0.297057
# Iteration 173, loss = 498990.71560936
# Validation score: 0.300011
# Iteration 174, loss = 496732.91841043
# Validation score: 0.302868
# Iteration 175, loss = 494365.93920202
# Validation score: 0.305637
# Iteration 176, loss = 492159.89165045
# Validation score: 0.308487
# Iteration 177, loss = 490007.53566252
# Validation score: 0.311356
# Iteration 178, loss = 487867.45129093
# Validation score: 0.313887
# Iteration 179, loss = 485660.86523710
# Validation score: 0.316442
# Iteration 180, loss = 483366.58522766
# Validation score: 0.319310
# Iteration 181, loss = 481375.92969943
# Validation score: 0.321825
# Iteration 182, loss = 479119.47309410
# Validation score: 0.323641
# Iteration 183, loss = 477138.93644191
# Validation score: 0.325559
# Iteration 184, loss = 475015.83640131
# Validation score: 0.327583
# Iteration 185, loss = 472867.72375112
# Validation score: 0.329645
# Iteration 186, loss = 470919.14721937
# Validation score: 0.331757
# Iteration 187, loss = 468828.56409993
# Validation score: 0.333925
# Iteration 188, loss = 466722.45497235
# Validation score: 0.335984
# Iteration 189, loss = 464662.28102928
# Validation score: 0.337858
# Iteration 190, loss = 462709.01954760
# Validation score: 0.339777
# Iteration 191, loss = 460662.03205434
# Validation score: 0.341811
# Iteration 192, loss = 458675.86268471
# Validation score: 0.344201
# Iteration 193, loss = 456553.59126758
# Validation score: 0.346813
# Iteration 194, loss = 454624.25167774
# Validation score: 0.349513
# Iteration 195, loss = 452642.37706884
# Validation score: 0.351833
# Iteration 196, loss = 450602.85688738
# Validation score: 0.353632
# Iteration 197, loss = 448752.61345551
# Validation score: 0.355322
# Iteration 198, loss = 446839.28994920
# Validation score: 0.356782
# Iteration 199, loss = 444954.69918898
# Validation score: 0.358124
# Iteration 200, loss = 442922.06573979
# Validation score: 0.359544
# Iteration 201, loss = 441218.77006727
# Validation score: 0.360701
# Iteration 202, loss = 439278.33736945
# Validation score: 0.361861
# Iteration 203, loss = 437387.57398045
# Validation score: 0.362846
# Iteration 204, loss = 435643.06818311
# Validation score: 0.363542
# Iteration 205, loss = 433756.06304692
# Validation score: 0.364325
# Iteration 206, loss = 432130.45817037
# Validation score: 0.365360
# Iteration 207, loss = 430267.93055508
# Validation score: 0.366239
# Iteration 208, loss = 428502.95137376
# Validation score: 0.367326
# Iteration 209, loss = 426901.62224469
# Validation score: 0.368440
# Iteration 210, loss = 425134.91251752
# Validation score: 0.369788
# Iteration 211, loss = 423464.20885793
# Validation score: 0.371320
# Iteration 212, loss = 421815.56471199
# Validation score: 0.373089
# Iteration 213, loss = 420082.78680500
# Validation score: 0.374478
# Iteration 214, loss = 418343.50180800
# Validation score: 0.376477
# Iteration 215, loss = 416680.86823215
# Validation score: 0.378122
# Iteration 216, loss = 415047.89414340
# Validation score: 0.379900
# Iteration 217, loss = 413360.71828042
# Validation score: 0.381616
# Iteration 218, loss = 411735.26226039
# Validation score: 0.383362
# Iteration 219, loss = 410130.99326171
# Validation score: 0.385231
# Iteration 220, loss = 408475.09860833
# Validation score: 0.387038
# Iteration 221, loss = 406878.83887104
# Validation score: 0.388795
# Iteration 222, loss = 405348.02192304
# Validation score: 0.390699
# Iteration 223, loss = 403637.81707603
# Validation score: 0.392455
# Iteration 224, loss = 402112.88815224
# Validation score: 0.394432
# Iteration 225, loss = 400598.73698701
# Validation score: 0.396082
# Iteration 226, loss = 399145.23347605
# Validation score: 0.398424
# Iteration 227, loss = 397482.94470001
# Validation score: 0.401560
# Iteration 228, loss = 395878.32479164
# Validation score: 0.404127
# Iteration 229, loss = 394289.79824141
# Validation score: 0.406453
# Iteration 230, loss = 392745.18517273
# Validation score: 0.408534
# Iteration 231, loss = 391078.42268367
# Validation score: 0.410448
# Iteration 232, loss = 389670.04779944
# Validation score: 0.412301
# Iteration 233, loss = 388090.23116242
# Validation score: 0.413978
# Iteration 234, loss = 386606.56441757
# Validation score: 0.415620
# Iteration 235, loss = 385111.19247721
# Validation score: 0.417177
# Iteration 236, loss = 383616.66618377
# Validation score: 0.418647
# Iteration 237, loss = 382194.23794141
# Validation score: 0.420267
# Iteration 238, loss = 380646.29324546
# Validation score: 0.421630
# Iteration 239, loss = 379186.45522790
# Validation score: 0.423109
# Iteration 240, loss = 377776.96206683
# Validation score: 0.424217
# Iteration 241, loss = 376299.09380777
# Validation score: 0.425538
# Iteration 242, loss = 374930.82395858
# Validation score: 0.426792
# Iteration 243, loss = 373490.00256508
# Validation score: 0.427658
# Iteration 244, loss = 372068.62041054
# Validation score: 0.428586
# Iteration 245, loss = 370626.30499141
# Validation score: 0.429759
# Iteration 246, loss = 369235.96099308
# Validation score: 0.431068
# Iteration 247, loss = 367901.85774206
# Validation score: 0.432277
# Iteration 248, loss = 366453.64405462
# Validation score: 0.433470
# Iteration 249, loss = 365134.19482532
# Validation score: 0.435025
# Iteration 250, loss = 363633.64103436
# Validation score: 0.436032
# Iteration 251, loss = 362347.17180016
# Validation score: 0.437160
# Iteration 252, loss = 360932.70186395
# Validation score: 0.438289
# Iteration 253, loss = 359599.41446200
# Validation score: 0.439256
# Iteration 254, loss = 358278.69216696
# Validation score: 0.440389
# Iteration 255, loss = 356907.02834595
# Validation score: 0.441653
# Iteration 256, loss = 355755.93332174
# Validation score: 0.443335
# Iteration 257, loss = 354334.80702091
# Validation score: 0.445247
# Iteration 258, loss = 353065.04430287
# Validation score: 0.447189
# Iteration 259, loss = 351617.50234978
# Validation score: 0.448780
# Iteration 260, loss = 350401.34850388
# Validation score: 0.450621
# Iteration 261, loss = 349100.06374777
# Validation score: 0.452386
# Iteration 262, loss = 347834.82942981
# Validation score: 0.454001
# Iteration 263, loss = 346532.53027618
# Validation score: 0.455730
# Iteration 264, loss = 345367.89957326
# Validation score: 0.457386
# Iteration 265, loss = 344158.99805011
# Validation score: 0.458687
# Iteration 266, loss = 342864.69172364
# Validation score: 0.459913
# Iteration 267, loss = 341597.48547268
# Validation score: 0.461072
# Iteration 268, loss = 340346.49294856
# Validation score: 0.462439
# Iteration 269, loss = 339182.28542561
# Validation score: 0.463812
# Iteration 270, loss = 337947.04257574
# Validation score: 0.465327
# Iteration 271, loss = 336756.89158942
# Validation score: 0.466468
# Iteration 272, loss = 335578.78120495
# Validation score: 0.467187
# Iteration 273, loss = 334323.71164824
# Validation score: 0.468301
# Iteration 274, loss = 333150.94970256
# Validation score: 0.469558
# Iteration 275, loss = 332056.28060822
# Validation score: 0.470865
# Iteration 276, loss = 330793.87690565
# Validation score: 0.472474
# Iteration 277, loss = 329671.02264094
# Validation score: 0.474097
# Iteration 278, loss = 328464.12622670
# Validation score: 0.476225
# Iteration 279, loss = 327344.32168646
# Validation score: 0.477900
# Iteration 280, loss = 326246.94523833
# Validation score: 0.479214
# Iteration 281, loss = 325129.47089764
# Validation score: 0.480503
# Iteration 282, loss = 323925.25715865
# Validation score: 0.481198
# Iteration 283, loss = 322797.84576615
# Validation score: 0.481734
# Iteration 284, loss = 321620.74487929
# Validation score: 0.482278
# Iteration 285, loss = 320577.11093375
# Validation score: 0.482961
# Iteration 286, loss = 319368.08571125
# Validation score: 0.483501
# Iteration 287, loss = 318249.82515632
# Validation score: 0.483988
# Iteration 288, loss = 317154.79065361
# Validation score: 0.484862
# Iteration 289, loss = 316110.91610493
# Validation score: 0.486049
# Iteration 290, loss = 314987.48609143
# Validation score: 0.487143
# Iteration 291, loss = 313868.40364829
# Validation score: 0.487841
# Iteration 292, loss = 312858.16132153
# Validation score: 0.488600
# Iteration 293, loss = 311712.77648516
# Validation score: 0.489698
# Iteration 294, loss = 310673.54669085
# Validation score: 0.490955
# Iteration 295, loss = 309667.01879853
# Validation score: 0.491922
# Iteration 296, loss = 308566.09576544
# Validation score: 0.493312
# Iteration 297, loss = 307545.49779399
# Validation score: 0.494962
# Iteration 298, loss = 306469.59187234
# Validation score: 0.496518
# Iteration 299, loss = 305451.20936626
# Validation score: 0.498363
# Iteration 300, loss = 304335.52223956
# Validation score: 0.499864
# Iteration 301, loss = 303492.87608158
# Validation score: 0.501135
# Iteration 302, loss = 302277.98402426
# Validation score: 0.501984
# Iteration 303, loss = 301355.86655318
# Validation score: 0.502958
# Iteration 304, loss = 300323.98075854
# Validation score: 0.504513
# Iteration 305, loss = 299283.40108717
# Validation score: 0.505961
# Iteration 306, loss = 298256.93363047
# Validation score: 0.507343
# Iteration 307, loss = 297367.10487185
# Validation score: 0.508839
# Iteration 308, loss = 296216.08607480
# Validation score: 0.510195
# Iteration 309, loss = 295287.78412932
# Validation score: 0.511651
# Iteration 310, loss = 294267.83498642
# Validation score: 0.513178
# Iteration 311, loss = 293375.88611101
# Validation score: 0.514497
# Iteration 312, loss = 292525.62447228
# Validation score: 0.516043
# Iteration 313, loss = 291350.63370429
# Validation score: 0.517709
# Iteration 314, loss = 290541.14531912
# Validation score: 0.519260
# Iteration 315, loss = 289512.46122102
# Validation score: 0.520687
# Iteration 316, loss = 288530.44259319
# Validation score: 0.521896
# Iteration 317, loss = 287605.54179657
# Validation score: 0.522568
# Iteration 318, loss = 286700.94810159
# Validation score: 0.523255
# Iteration 319, loss = 285705.61315155
# Validation score: 0.524030
# Iteration 320, loss = 284739.44940726
# Validation score: 0.524799
# Iteration 321, loss = 283854.08108544
# Validation score: 0.525398
# Iteration 322, loss = 283143.57779858
# Validation score: 0.525594
# Iteration 323, loss = 282090.32858311
# Validation score: 0.526622
# Iteration 324, loss = 281205.44810001
# Validation score: 0.527771
# Iteration 325, loss = 280310.88235859
# Validation score: 0.529111
# Iteration 326, loss = 279447.39640118
# Validation score: 0.530301
# Iteration 327, loss = 278643.11811151
# Validation score: 0.531349
# Iteration 328, loss = 277720.43999314
# Validation score: 0.532186
# Iteration 329, loss = 276829.01549264
# Validation score: 0.532647
# Iteration 330, loss = 275869.02055784
# Validation score: 0.533248
# Iteration 331, loss = 275032.06098488
# Validation score: 0.533773
# Iteration 332, loss = 274177.64295464
# Validation score: 0.534333
# Iteration 333, loss = 273344.52970065
# Validation score: 0.535396
# Iteration 334, loss = 272485.00958604
# Validation score: 0.536764
# Iteration 335, loss = 271580.00111354
# Validation score: 0.538356
# Iteration 336, loss = 270784.87738122
# Validation score: 0.540237
# Iteration 337, loss = 269913.94111985
# Validation score: 0.541847
# Iteration 338, loss = 269080.67195434
# Validation score: 0.543118
# Iteration 339, loss = 268205.23735422
# Validation score: 0.544345
# Iteration 340, loss = 267423.17464652
# Validation score: 0.545526
# Iteration 341, loss = 266559.36386388
# Validation score: 0.546449
# Iteration 342, loss = 265760.31655512
# Validation score: 0.547492
# Iteration 343, loss = 265028.03909212
# Validation score: 0.548585
# Iteration 344, loss = 264010.57181041
# Validation score: 0.549614
# Iteration 345, loss = 263275.76135824
# Validation score: 0.550471
# Iteration 346, loss = 262423.74483236
# Validation score: 0.551593
# Iteration 347, loss = 261539.50603466
# Validation score: 0.553060
# Iteration 348, loss = 260800.10640395
# Validation score: 0.554344
# Iteration 349, loss = 259981.43550437
# Validation score: 0.555598
# Iteration 350, loss = 259185.53792985
# Validation score: 0.556768
# Iteration 351, loss = 258427.37173278
# Validation score: 0.558224
# Iteration 352, loss = 257588.80623353
# Validation score: 0.559807
# Iteration 353, loss = 256842.06783503
# Validation score: 0.561301
# Iteration 354, loss = 256069.08850670
# Validation score: 0.562817
# Iteration 355, loss = 255260.68696489
# Validation score: 0.563901
# Iteration 356, loss = 254487.64705545
# Validation score: 0.564575
# Iteration 357, loss = 253757.63367898
# Validation score: 0.565215
# Iteration 358, loss = 252985.36949047
# Validation score: 0.565800
# Iteration 359, loss = 252194.34040090
# Validation score: 0.566623
# Iteration 360, loss = 251411.81077095
# Validation score: 0.567180
# Iteration 361, loss = 250745.49470451
# Validation score: 0.567980
# Iteration 362, loss = 249942.29809457
# Validation score: 0.568912
# Iteration 363, loss = 249183.64712892
# Validation score: 0.569685
# Iteration 364, loss = 248380.50393704
# Validation score: 0.570039
# Iteration 365, loss = 247685.17494438
# Validation score: 0.570411
# Iteration 366, loss = 246923.39214677
# Validation score: 0.570854
# Iteration 367, loss = 246162.23271478
# Validation score: 0.571263
# Iteration 368, loss = 245523.55741374
# Validation score: 0.571557
# Iteration 369, loss = 244791.45729236
# Validation score: 0.572059
# Iteration 370, loss = 244018.92778820
# Validation score: 0.572971
# Iteration 371, loss = 243308.21950301
# Validation score: 0.574070
# Iteration 372, loss = 242606.01038586
# Validation score: 0.574962
# Iteration 373, loss = 241830.06171057
# Validation score: 0.575894
# Iteration 374, loss = 241090.95519862
# Validation score: 0.576714
# Iteration 375, loss = 240327.68082822
# Validation score: 0.577065
# Iteration 376, loss = 239745.88021664
# Validation score: 0.577291
# Iteration 377, loss = 239096.72501748
# Validation score: 0.578032
# Iteration 378, loss = 238297.34772684
# Validation score: 0.579048
# Iteration 379, loss = 237632.66266191
# Validation score: 0.579737
# Iteration 380, loss = 236897.60466242
# Validation score: 0.580259
# Iteration 381, loss = 236267.20408816
# Validation score: 0.581405
# Iteration 382, loss = 235579.76639751
# Validation score: 0.582815
# Iteration 383, loss = 234904.06142022
# Validation score: 0.584303
# Iteration 384, loss = 234218.86027932
# Validation score: 0.585401
# Iteration 385, loss = 233579.73063973
# Validation score: 0.586199
# Iteration 386, loss = 232934.13651024
# Validation score: 0.586849
# Iteration 387, loss = 232238.90187171
# Validation score: 0.587666
# Iteration 388, loss = 231623.20600118
# Validation score: 0.588498
# Iteration 389, loss = 230876.12910300
# Validation score: 0.589908
# Iteration 390, loss = 230342.83655124
# Validation score: 0.591262
# Iteration 391, loss = 229637.51630905
# Validation score: 0.592774
# Iteration 392, loss = 229010.14234967
# Validation score: 0.594085
# Iteration 393, loss = 228298.30241107
# Validation score: 0.595230
# Iteration 394, loss = 227717.39604828
# Validation score: 0.596049
# Iteration 395, loss = 227001.40821534
# Validation score: 0.596905
# Iteration 396, loss = 226307.15789976
# Validation score: 0.597500
# Iteration 397, loss = 225747.36084610
# Validation score: 0.598118
# Iteration 398, loss = 225032.85573880
# Validation score: 0.598827
# Iteration 399, loss = 224368.94690923
# Validation score: 0.599635
# Iteration 400, loss = 223814.80974817
# Validation score: 0.600270
# Iteration 401, loss = 223174.92094093
# Validation score: 0.601475
# Iteration 402, loss = 222524.38422790
# Validation score: 0.602664
# Iteration 403, loss = 221930.41190829
# Validation score: 0.603787
# Iteration 404, loss = 221259.56135429
# Validation score: 0.604590
# Iteration 405, loss = 220687.34907390
# Validation score: 0.605181
# Iteration 406, loss = 220096.74365372
# Validation score: 0.605775
# Iteration 407, loss = 219395.64514844
# Validation score: 0.606367
# Iteration 408, loss = 218803.29841216
# Validation score: 0.607085
# Iteration 409, loss = 218296.09729641
# Validation score: 0.607684
# Iteration 410, loss = 217603.13272849
# Validation score: 0.608480
# Iteration 411, loss = 216936.43409699
# Validation score: 0.609641
# Iteration 412, loss = 216378.58621214
# Validation score: 0.610733
# Iteration 413, loss = 215694.47958209
# Validation score: 0.612299
# Iteration 414, loss = 215171.17741858
# Validation score: 0.613666
# Iteration 415, loss = 214573.67049830
# Validation score: 0.615094
# Iteration 416, loss = 214023.17508133
# Validation score: 0.616169
# Iteration 417, loss = 213400.76042403
# Validation score: 0.617224
# Iteration 418, loss = 212910.71946378
# Validation score: 0.618496
# Iteration 419, loss = 212295.30474262
# Validation score: 0.619105
# Iteration 420, loss = 211700.17051978
# Validation score: 0.619956
# Iteration 421, loss = 211151.79755795
# Validation score: 0.620719
# Iteration 422, loss = 210615.33702004
# Validation score: 0.621267
# Iteration 423, loss = 210005.16355083
# Validation score: 0.621284
# Iteration 424, loss = 209394.14375292
# Validation score: 0.621588
# Iteration 425, loss = 208808.41503383
# Validation score: 0.622092
# Iteration 426, loss = 208339.29588318
# Validation score: 0.622509
# Iteration 427, loss = 207783.39668651
# Validation score: 0.623286
# Iteration 428, loss = 207187.88983781
# Validation score: 0.623994
# Iteration 429, loss = 206704.69416455
# Validation score: 0.625367
# Iteration 430, loss = 206159.13215059
# Validation score: 0.626531
# Iteration 431, loss = 205543.73878004
# Validation score: 0.627206
# Iteration 432, loss = 204913.14821575
# Validation score: 0.628307
# Iteration 433, loss = 204357.10857976
# Validation score: 0.629095
# Iteration 434, loss = 203838.11406874
# Validation score: 0.629426
# Iteration 435, loss = 203419.65846462
# Validation score: 0.630051
# Iteration 436, loss = 202913.92407858
# Validation score: 0.630638
# Iteration 437, loss = 202387.83345302
# Validation score: 0.631149
# Iteration 438, loss = 201879.33804430
# Validation score: 0.631804
# Iteration 439, loss = 201349.03188579
# Validation score: 0.632483
# Iteration 440, loss = 200789.69920745
# Validation score: 0.633256
# Iteration 441, loss = 200276.05349704
# Validation score: 0.634070
# Iteration 442, loss = 199716.81233557
# Validation score: 0.635516
# Iteration 443, loss = 199157.51892335
# Validation score: 0.637180
# Iteration 444, loss = 198646.20207598
# Validation score: 0.638782
# Iteration 445, loss = 198175.08517829
# Validation score: 0.639977
# Iteration 446, loss = 197723.77785178
# Validation score: 0.640692
# Iteration 447, loss = 197201.56844284
# Validation score: 0.640827
# Iteration 448, loss = 196659.16428080
# Validation score: 0.640817
# Iteration 449, loss = 196226.58765628
# Validation score: 0.640915
# Iteration 450, loss = 195648.19026301
# Validation score: 0.641476
# Iteration 451, loss = 195254.35682990
# Validation score: 0.642288
# Iteration 452, loss = 194679.05011271
# Validation score: 0.643465
# Iteration 453, loss = 194238.96648710
# Validation score: 0.644381
# Iteration 454, loss = 193702.10494700
# Validation score: 0.644707
# Iteration 455, loss = 193171.10918455
# Validation score: 0.645250
# Iteration 456, loss = 192665.93407495
# Validation score: 0.645723
# Iteration 457, loss = 192178.45321981
# Validation score: 0.646356
# Iteration 458, loss = 191692.34798525
# Validation score: 0.647021
# Iteration 459, loss = 191248.90066447
# Validation score: 0.647715
# Iteration 460, loss = 190845.01226596
# Validation score: 0.648542
# Iteration 461, loss = 190322.55463515
# Validation score: 0.649125
# Iteration 462, loss = 189855.66666190
# Validation score: 0.649572
# Iteration 463, loss = 189454.57724313
# Validation score: 0.649699
# Iteration 464, loss = 188910.83875922
# Validation score: 0.649976
# Iteration 465, loss = 188462.71330197
# Validation score: 0.650638
# Iteration 466, loss = 188025.99004010
# Validation score: 0.651205
# Iteration 467, loss = 187566.64803580
# Validation score: 0.651943
# Iteration 468, loss = 187105.61877875
# Validation score: 0.652920
# Iteration 469, loss = 186649.14508085
# Validation score: 0.653865
# Iteration 470, loss = 186264.34422959
# Validation score: 0.655004
# Iteration 471, loss = 185737.46979380
# Validation score: 0.655675
# Iteration 472, loss = 185298.96995843
# Validation score: 0.656467
# Iteration 473, loss = 184887.49072699
# Validation score: 0.657418
# Iteration 474, loss = 184444.86303250
# Validation score: 0.658126
# Iteration 475, loss = 183989.04227181
# Validation score: 0.658812
# Iteration 476, loss = 183525.32912338
# Validation score: 0.659130
# Iteration 477, loss = 183159.17427808
# Validation score: 0.659826
# Iteration 478, loss = 182693.78910295
# Validation score: 0.660512
# Iteration 479, loss = 182250.76513476
# Validation score: 0.660956
# Iteration 480, loss = 181815.24669659
# Validation score: 0.661351
# Iteration 481, loss = 181360.69187291
# Validation score: 0.661729
# Iteration 482, loss = 180929.39159506
# Validation score: 0.661812
# Iteration 483, loss = 180614.12481794
# Validation score: 0.662112
# Iteration 484, loss = 180139.57956589
# Validation score: 0.662796
# Iteration 485, loss = 179719.75133365
# Validation score: 0.663489
# Iteration 486, loss = 179312.64803406
# Validation score: 0.664103
# Iteration 487, loss = 178919.30141502
# Validation score: 0.664429
# Iteration 488, loss = 178490.57388588
# Validation score: 0.664525
# Iteration 489, loss = 178068.55585337
# Validation score: 0.665000
# Iteration 490, loss = 177695.74854667
# Validation score: 0.665600
# Iteration 491, loss = 177254.93280808
# Validation score: 0.666625
# Iteration 492, loss = 176813.11819075
# Validation score: 0.667655
# Iteration 493, loss = 176514.83866709
# Validation score: 0.668653
# Iteration 494, loss = 175976.98295128
# Validation score: 0.669778
# Iteration 495, loss = 175611.13037724
# Validation score: 0.671026
# Iteration 496, loss = 175209.89487280
# Validation score: 0.672387
# Iteration 497, loss = 174928.82382475
# Validation score: 0.673463
# Iteration 498, loss = 174427.19327787
# Validation score: 0.674341
# Iteration 499, loss = 174072.55685907
# Validation score: 0.675461
# Iteration 500, loss = 173739.20675278
# Validation score: 0.676637
# Iteration 501, loss = 173340.22251251
# Validation score: 0.677467
# Iteration 502, loss = 173018.51846012
# Validation score: 0.678325
# Iteration 503, loss = 172656.39387883
# Validation score: 0.679209
# Iteration 504, loss = 172282.96575776
# Validation score: 0.679758
# Iteration 505, loss = 171873.23191836
# Validation score: 0.680241
# Iteration 506, loss = 171459.75504377
# Validation score: 0.680302
# Iteration 507, loss = 171053.99320776
# Validation score: 0.680468
# Iteration 508, loss = 170670.31217349
# Validation score: 0.680424
# Iteration 509, loss = 170325.78855943
# Validation score: 0.680312
# Iteration 510, loss = 169965.23526127
# Validation score: 0.680139
# Iteration 511, loss = 169599.65391740
# Validation score: 0.680272
# Iteration 512, loss = 169218.01235520
# Validation score: 0.680675
# Iteration 513, loss = 168856.43712393
# Validation score: 0.681350
# Iteration 514, loss = 168521.98740436
# Validation score: 0.681807
# Iteration 515, loss = 168145.83591241
# Validation score: 0.682388
# Iteration 516, loss = 167780.82098512
# Validation score: 0.682797
# Iteration 517, loss = 167393.73406621
# Validation score: 0.683120
# Iteration 518, loss = 167123.32968052
# Validation score: 0.683636
# Iteration 519, loss = 166755.90362943
# Validation score: 0.684159
# Iteration 520, loss = 166474.81001204
# Validation score: 0.685037
# Iteration 521, loss = 166169.84036658
# Validation score: 0.685919
# Iteration 522, loss = 165890.98693884
# Validation score: 0.686806
# Iteration 523, loss = 165500.31705253
# Validation score: 0.687930
# Iteration 524, loss = 165211.86209901
# Validation score: 0.688837
# Iteration 525, loss = 164859.64873063
# Validation score: 0.690235
# Iteration 526, loss = 164556.77720514
# Validation score: 0.691565
# Iteration 527, loss = 164376.36425932
# Validation score: 0.692494
# Iteration 528, loss = 164019.68824690
# Validation score: 0.693213
# Iteration 529, loss = 163619.56129171
# Validation score: 0.693747
# Iteration 530, loss = 163230.98574408
# Validation score: 0.693976
# Iteration 531, loss = 162842.90465613
# Validation score: 0.693906
# Iteration 532, loss = 162578.20830706
# Validation score: 0.693839
# Iteration 533, loss = 162133.84928176
# Validation score: 0.693619
# Iteration 534, loss = 161861.21375379
# Validation score: 0.693604
# Iteration 535, loss = 161605.48160524
# Validation score: 0.694077
# Iteration 536, loss = 161257.30548395
# Validation score: 0.694714
# Iteration 537, loss = 160897.15146872
# Validation score: 0.695268
# Iteration 538, loss = 160593.91463967
# Validation score: 0.696006
# Iteration 539, loss = 160291.34742089
# Validation score: 0.696795
# Iteration 540, loss = 159995.77469036
# Validation score: 0.697503
# Iteration 541, loss = 159705.05889507
# Validation score: 0.698500
# Iteration 542, loss = 159291.00621947
# Validation score: 0.699182
# Iteration 543, loss = 159035.96199227
# Validation score: 0.699635
# Iteration 544, loss = 158731.58493732
# Validation score: 0.700138
# Iteration 545, loss = 158377.46937554
# Validation score: 0.700934
# Iteration 546, loss = 158123.65490170
# Validation score: 0.701616
# Iteration 547, loss = 157869.95879160
# Validation score: 0.702282
# Iteration 548, loss = 157573.01305346
# Validation score: 0.702706
# Iteration 549, loss = 157239.00144869
# Validation score: 0.703361
# Iteration 550, loss = 156940.66094359
# Validation score: 0.703716
# Iteration 551, loss = 156685.99633260
# Validation score: 0.703757
# Iteration 552, loss = 156315.84085581
# Validation score: 0.703714
# Iteration 553, loss = 156095.77804386
# Validation score: 0.703561
# Iteration 554, loss = 155786.83690414
# Validation score: 0.703580
# Iteration 555, loss = 155512.35689230
# Validation score: 0.703911
# Iteration 556, loss = 155242.28341334
# Validation score: 0.704303
# Iteration 557, loss = 154959.89079032
# Validation score: 0.704597
# Iteration 558, loss = 154627.18596214
# Validation score: 0.705373
# Iteration 559, loss = 154386.39513448
# Validation score: 0.706235
# Iteration 560, loss = 154111.25641320
# Validation score: 0.706685
# Iteration 561, loss = 153882.74781712
# Validation score: 0.707211
# Iteration 562, loss = 153567.45497839
# Validation score: 0.707787
# Iteration 563, loss = 153535.30442184
# Validation score: 0.708235
# Iteration 564, loss = 153029.76602929
# Validation score: 0.709116
# Iteration 565, loss = 152815.09536985
# Validation score: 0.710251
# Iteration 566, loss = 152505.95627894
# Validation score: 0.711143
# Iteration 567, loss = 152284.19089341
# Validation score: 0.712249
# Iteration 568, loss = 152097.50320320
# Validation score: 0.713119
# Iteration 569, loss = 151809.28398041
# Validation score: 0.713765
# Iteration 570, loss = 151532.22044868
# Validation score: 0.714259
# Iteration 571, loss = 151294.27848552
# Validation score: 0.714418
# Iteration 572, loss = 151007.37692403
# Validation score: 0.714681
# Iteration 573, loss = 150830.82924842
# Validation score: 0.714939
# Iteration 574, loss = 150502.25060977
# Validation score: 0.715217
# Iteration 575, loss = 150314.19824895
# Validation score: 0.715638
# Iteration 576, loss = 149983.74457014
# Validation score: 0.716307
# Iteration 577, loss = 149712.83625653
# Validation score: 0.716927
# Iteration 578, loss = 149462.66144848
# Validation score: 0.717380
# Iteration 579, loss = 149154.13788172
# Validation score: 0.717459
# Iteration 580, loss = 148906.31200337
# Validation score: 0.717322
# Iteration 581, loss = 148717.19181593
# Validation score: 0.717265
# Iteration 582, loss = 148483.73652186
# Validation score: 0.717162
# Iteration 583, loss = 148281.54589838
# Validation score: 0.717275
# Iteration 584, loss = 148048.11457527
# Validation score: 0.717409
# Iteration 585, loss = 147820.10525953
# Validation score: 0.717434
# Iteration 586, loss = 147587.05565960
# Validation score: 0.717665
# Iteration 587, loss = 147292.37160483
# Validation score: 0.717624
# Iteration 588, loss = 147091.80984750
# Validation score: 0.717716
# Iteration 589, loss = 146928.61781505
# Validation score: 0.718186
# Iteration 590, loss = 146582.62488701
# Validation score: 0.719179
# Iteration 591, loss = 146321.61540472
# Validation score: 0.720101
# Iteration 592, loss = 146057.90864796
# Validation score: 0.720953
# Iteration 593, loss = 145844.86733844
# Validation score: 0.721739
# Iteration 594, loss = 145596.16500080
# Validation score: 0.722056
# Iteration 595, loss = 145318.81137412
# Validation score: 0.722646
# Iteration 596, loss = 145045.13967091
# Validation score: 0.723181
# Iteration 597, loss = 144842.41123272
# Validation score: 0.723769
# Iteration 598, loss = 144637.23250522
# Validation score: 0.724328
# Iteration 599, loss = 144449.01433176
# Validation score: 0.724585
# Iteration 600, loss = 144242.70570462
# Validation score: 0.725089
# Iteration 601, loss = 143982.46436930
# Validation score: 0.725666
# Iteration 602, loss = 143791.41469914
# Validation score: 0.726213
# Iteration 603, loss = 143535.53220903
# Validation score: 0.726560
# Iteration 604, loss = 143276.19922491
# Validation score: 0.726887
# Iteration 605, loss = 143085.74815892
# Validation score: 0.727001
# Iteration 606, loss = 142887.57170332
# Validation score: 0.727316
# Iteration 607, loss = 142726.12762761
# Validation score: 0.727101
# Iteration 608, loss = 142379.05366124
# Validation score: 0.727433
# Iteration 609, loss = 142147.61705538
# Validation score: 0.727950
# Iteration 610, loss = 141924.16969919
# Validation score: 0.728541
# Iteration 611, loss = 141741.69201222
# Validation score: 0.729361
# Iteration 612, loss = 141560.52028073
# Validation score: 0.730013
# Iteration 613, loss = 141423.15757054
# Validation score: 0.730746
# Iteration 614, loss = 141232.15195708
# Validation score: 0.731005
# Iteration 615, loss = 141153.92450251
# Validation score: 0.731056
# Iteration 616, loss = 140819.17917367
# Validation score: 0.730875
# Iteration 617, loss = 140662.72402853
# Validation score: 0.730710
# Iteration 618, loss = 140415.49557370
# Validation score: 0.730715
# Iteration 619, loss = 140193.25392102
# Validation score: 0.730961
# Iteration 620, loss = 139967.36973861
# Validation score: 0.731360
# Iteration 621, loss = 139798.84339538
# Validation score: 0.732028
# Iteration 622, loss = 139607.68429928
# Validation score: 0.732618
# Iteration 623, loss = 139331.72172615
# Validation score: 0.733181
# Iteration 624, loss = 139132.20907296
# Validation score: 0.733912
# Iteration 625, loss = 138950.69487496
# Validation score: 0.734741
# Iteration 626, loss = 138709.42924257
# Validation score: 0.735395
# Iteration 627, loss = 138551.05425824
# Validation score: 0.735808
# Iteration 628, loss = 138472.22884219
# Validation score: 0.736146
# Iteration 629, loss = 138326.56350541
# Validation score: 0.736450
# Iteration 630, loss = 138090.34146304
# Validation score: 0.736964
# Iteration 631, loss = 138032.95624872
# Validation score: 0.737373
# Iteration 632, loss = 137665.67733518
# Validation score: 0.738093
# Iteration 633, loss = 137567.26038713
# Validation score: 0.738598
# Iteration 634, loss = 137313.56039118
# Validation score: 0.739125
# Iteration 635, loss = 137117.84343463
# Validation score: 0.739893
# Iteration 636, loss = 136917.15598926
# Validation score: 0.740407
# Iteration 637, loss = 136733.35058027
# Validation score: 0.740847
# Iteration 638, loss = 136584.90451763
# Validation score: 0.741104
# Iteration 639, loss = 136314.18451760
# Validation score: 0.740998
# Iteration 640, loss = 136137.54463618
# Validation score: 0.740478
# Iteration 641, loss = 136018.45934498
# Validation score: 0.739930
# Iteration 642, loss = 135840.34707915
# Validation score: 0.739519
# Iteration 643, loss = 135693.79665555
# Validation score: 0.739395
# Iteration 644, loss = 135536.93779576
# Validation score: 0.739785
# Iteration 645, loss = 135326.79067879
# Validation score: 0.740474
# Iteration 646, loss = 135248.67776672
# Validation score: 0.740779
# Iteration 647, loss = 135002.41932853
# Validation score: 0.740668
# Iteration 648, loss = 134796.86496516
# Validation score: 0.740749
# Iteration 649, loss = 134613.24345367
# Validation score: 0.740707
# Iteration 650, loss = 134455.82175387
# Validation score: 0.740579
# Iteration 651, loss = 134253.33303326
# Validation score: 0.740753
# Iteration 652, loss = 134085.07879524
# Validation score: 0.740968
# Iteration 653, loss = 133956.40566599
# Validation score: 0.741409
# Iteration 654, loss = 133834.66873425
# Validation score: 0.742034
# Iteration 655, loss = 133614.22343889
# Validation score: 0.742532
# Iteration 656, loss = 133443.83929716
# Validation score: 0.742823
# Iteration 657, loss = 133225.71988105
# Validation score: 0.743450
# Iteration 658, loss = 133147.14993082
# Validation score: 0.744106
# Iteration 659, loss = 132895.36748680
# Validation score: 0.744539
# Iteration 660, loss = 132747.16663502
# Validation score: 0.745221
# Iteration 661, loss = 132662.81174397
# Validation score: 0.745953
# Iteration 662, loss = 132401.22410047
# Validation score: 0.746522
# Iteration 663, loss = 132305.96904580
# Validation score: 0.747318
# Iteration 664, loss = 132238.17418300
# Validation score: 0.747737
# Iteration 665, loss = 132073.20748382
# Validation score: 0.747789
# Iteration 666, loss = 131906.86636196
# Validation score: 0.747668
# Iteration 667, loss = 131748.49679702
# Validation score: 0.747848
# Iteration 668, loss = 131629.80040503
# Validation score: 0.747781
# Iteration 669, loss = 131478.61770120
# Validation score: 0.747524
# Iteration 670, loss = 131277.34452823
# Validation score: 0.747422
# Iteration 671, loss = 131070.49330587
# Validation score: 0.747169
# Iteration 672, loss = 130939.81284125
# Validation score: 0.747088
# Iteration 673, loss = 130859.25943180
# Validation score: 0.747498
# Iteration 674, loss = 130588.16031065
# Validation score: 0.747842
# Iteration 675, loss = 130400.52290268
# Validation score: 0.748545
# Iteration 676, loss = 130389.48356480
# Validation score: 0.749349
# Iteration 677, loss = 130105.80815688
# Validation score: 0.750046
# Iteration 678, loss = 130014.13865179
# Validation score: 0.750795
# Iteration 679, loss = 129810.61356906
# Validation score: 0.751610
# Iteration 680, loss = 129736.33004724
# Validation score: 0.752497
# Iteration 681, loss = 129650.66018286
# Validation score: 0.753321
# Iteration 682, loss = 129405.24957257
# Validation score: 0.754091
# Iteration 683, loss = 129273.81845584
# Validation score: 0.754983
# Iteration 684, loss = 129308.93127464
# Validation score: 0.755791
# Iteration 685, loss = 129177.62072633
# Validation score: 0.756438
# Iteration 686, loss = 128978.41035985
# Validation score: 0.756609
# Iteration 687, loss = 128803.23251962
# Validation score: 0.756620
# Iteration 688, loss = 128601.23631217
# Validation score: 0.756493
# Iteration 689, loss = 128503.38135625
# Validation score: 0.756156
# Iteration 690, loss = 128327.78905809
# Validation score: 0.755765
# Iteration 691, loss = 128150.43473154
# Validation score: 0.755620
# Iteration 692, loss = 128004.44127434
# Validation score: 0.755356
# Iteration 693, loss = 127889.90656546
# Validation score: 0.755176
# Iteration 694, loss = 127800.50060022
# Validation score: 0.754702
# Iteration 695, loss = 127656.17134534
# Validation score: 0.754497
# Iteration 696, loss = 127506.55339950
# Validation score: 0.754484
# Iteration 697, loss = 127376.84734552
# Validation score: 0.754316
# Iteration 698, loss = 127213.74985369
# Validation score: 0.754541
# Iteration 699, loss = 127151.07277675
# Validation score: 0.754867
# Iteration 700, loss = 126926.79066544
# Validation score: 0.755291
# Iteration 701, loss = 126771.55646644
# Validation score: 0.755842
# Iteration 702, loss = 126633.64553071
# Validation score: 0.756440
# Iteration 703, loss = 126546.99089448
# Validation score: 0.757115
# Iteration 704, loss = 126445.01390068
# Validation score: 0.757593
# Iteration 705, loss = 126332.98312318
# Validation score: 0.758080
# Iteration 706, loss = 126165.95399262
# Validation score: 0.758439
# Iteration 707, loss = 126036.41424400
# Validation score: 0.758871
# Iteration 708, loss = 125934.64045606
# Validation score: 0.759553
# Iteration 709, loss = 125782.75938291
# Validation score: 0.759682
# Iteration 710, loss = 125656.94696362
# Validation score: 0.759949
# Iteration 711, loss = 125517.26340167
# Validation score: 0.760006
# Iteration 712, loss = 125537.82577605
# Validation score: 0.760244
# Iteration 713, loss = 125388.62154757
# Validation score: 0.760371
# Iteration 714, loss = 125276.30969845
# Validation score: 0.760349
# Iteration 715, loss = 125185.95791070
# Validation score: 0.760312
# Iteration 716, loss = 125055.72762153
# Validation score: 0.760204
# Iteration 717, loss = 124896.86563218
# Validation score: 0.760363
# Iteration 718, loss = 124751.54207692
# Validation score: 0.760613
# Iteration 719, loss = 124610.29630844
# Validation score: 0.760764
# Iteration 720, loss = 124473.10023047
# Validation score: 0.761055
# Iteration 721, loss = 124346.96838666
# Validation score: 0.761140
# Iteration 722, loss = 124209.35084664
# Validation score: 0.761087
# Iteration 723, loss = 124094.32028277
# Validation score: 0.760888
# Iteration 724, loss = 123972.49337159
# Validation score: 0.760544
# Iteration 725, loss = 123902.14523920
# Validation score: 0.760155
# Iteration 726, loss = 123778.70292278
# Validation score: 0.760144
# Iteration 727, loss = 123711.70984804
# Validation score: 0.760399
# Iteration 728, loss = 123548.92722036
# Validation score: 0.760888
# Iteration 729, loss = 123525.66429758
# Validation score: 0.761387
# Iteration 730, loss = 123407.00771654
# Validation score: 0.761699
# Iteration 731, loss = 123205.84255185
# Validation score: 0.762082
# Iteration 732, loss = 123126.64902597
# Validation score: 0.762889
# Iteration 733, loss = 122990.85576931
# Validation score: 0.763467
# Iteration 734, loss = 122814.20865703
# Validation score: 0.764189
# Iteration 735, loss = 122716.00688492
# Validation score: 0.764971
# Iteration 736, loss = 122624.99022826
# Validation score: 0.765476
# Iteration 737, loss = 122514.30308676
# Validation score: 0.766087
# Iteration 738, loss = 122447.69339899
# Validation score: 0.766312
# Iteration 739, loss = 122308.98888417
# Validation score: 0.766262
# Iteration 740, loss = 122135.09912198
# Validation score: 0.765859
# Iteration 741, loss = 122133.87173198
# Validation score: 0.765308
# Iteration 742, loss = 121935.11386513
# Validation score: 0.765224
# Iteration 743, loss = 121920.66865562
# Validation score: 0.765121
# Iteration 744, loss = 121738.35722000
# Validation score: 0.764896
# Iteration 745, loss = 121640.66191133
# Validation score: 0.764638
# Iteration 746, loss = 121514.90901449
# Validation score: 0.764717
# Iteration 747, loss = 121472.13644767
# Validation score: 0.765078
# Iteration 748, loss = 121381.65953715
# Validation score: 0.765363
# Iteration 749, loss = 121270.14386361
# Validation score: 0.765495
# Iteration 750, loss = 121190.92952675
# Validation score: 0.765768
# Iteration 751, loss = 121041.24370515
# Validation score: 0.765783
# Iteration 752, loss = 120908.91571715
# Validation score: 0.765815
# Iteration 753, loss = 120828.62608458
# Validation score: 0.765935
# Iteration 754, loss = 120707.52721943
# Validation score: 0.766468
# Iteration 755, loss = 120652.20192019
# Validation score: 0.766908
# Iteration 756, loss = 120591.95695018
# Validation score: 0.767162
# Iteration 757, loss = 120510.97402787
# Validation score: 0.767543
# Iteration 758, loss = 120444.49839459
# Validation score: 0.768075
# Iteration 759, loss = 120284.43160404
# Validation score: 0.768738
# Iteration 760, loss = 120133.63696521
# Validation score: 0.769366
# Iteration 761, loss = 120103.54644492
# Validation score: 0.769781
# Iteration 762, loss = 120057.41890419
# Validation score: 0.770111
# Iteration 763, loss = 119962.05974868
# Validation score: 0.770262
# Iteration 764, loss = 119875.75031266
# Validation score: 0.770153
# Iteration 765, loss = 119759.55863090
# Validation score: 0.770160
# Iteration 766, loss = 119682.49374236
# Validation score: 0.770077
# Iteration 767, loss = 119530.97062452
# Validation score: 0.769871
# Iteration 768, loss = 119513.66814169
# Validation score: 0.769632
# Iteration 769, loss = 119383.53670808
# Validation score: 0.769506
# Iteration 770, loss = 119222.68141861
# Validation score: 0.769787
# Iteration 771, loss = 119113.23213145
# Validation score: 0.770051
# Iteration 772, loss = 119032.57105740
# Validation score: 0.770534
# Iteration 773, loss = 118941.51696737
# Validation score: 0.770995
# Iteration 774, loss = 118845.05808939
# Validation score: 0.771651
# Iteration 775, loss = 118819.50015581
# Validation score: 0.772013
# Iteration 776, loss = 118767.36467485
# Validation score: 0.771897
# Iteration 777, loss = 118647.69857240
# Validation score: 0.771371
# Iteration 778, loss = 118501.34372882
# Validation score: 0.771026
# Iteration 779, loss = 118487.99394013
# Validation score: 0.770691
# Iteration 780, loss = 118336.80482272
# Validation score: 0.770764
# Iteration 781, loss = 118240.97659047
# Validation score: 0.771153
# Iteration 782, loss = 118187.31728370
# Validation score: 0.771650
# Iteration 783, loss = 118018.75019845
# Validation score: 0.772215
# Iteration 784, loss = 117978.72839146
# Validation score: 0.772601
# Iteration 785, loss = 117897.19477816
# Validation score: 0.772953
# Iteration 786, loss = 117844.24296787
# Validation score: 0.773105
# Iteration 787, loss = 117710.26211283
# Validation score: 0.773128
# Iteration 788, loss = 117708.98947011
# Validation score: 0.773031
# Iteration 789, loss = 117538.41733915
# Validation score: 0.772727
# Iteration 790, loss = 117479.59579839
# Validation score: 0.772548
# Iteration 791, loss = 117468.58225456
# Validation score: 0.772616
# Iteration 792, loss = 117395.67794487
# Validation score: 0.772516
# Iteration 793, loss = 117266.33388239
# Validation score: 0.772659
# Iteration 794, loss = 117175.46815741
# Validation score: 0.772850
# Iteration 795, loss = 117086.63280180
# Validation score: 0.772808
# Iteration 796, loss = 117062.24609239
# Validation score: 0.772501
# Iteration 797, loss = 116920.88369915
# Validation score: 0.772322
# Iteration 798, loss = 116815.25008572
# Validation score: 0.772148
# Iteration 799, loss = 116755.77612556
# Validation score: 0.771917
# Iteration 800, loss = 116666.54077564
# Validation score: 0.771854
# Iteration 801, loss = 116578.29019758
# Validation score: 0.772015
# Iteration 802, loss = 116501.13431398
# Validation score: 0.772572
# Iteration 803, loss = 116435.54502307
# Validation score: 0.773329
# Iteration 804, loss = 116291.31838636
# Validation score: 0.773933
# Iteration 805, loss = 116287.63817788
# Validation score: 0.774593
# Iteration 806, loss = 116230.59324320
# Validation score: 0.775104
# Iteration 807, loss = 116090.79081931
# Validation score: 0.775366
# Iteration 808, loss = 116070.28490443
# Validation score: 0.775526
# Iteration 809, loss = 115964.11723040
# Validation score: 0.775639
# Iteration 810, loss = 115918.52799682
# Validation score: 0.776014
# Iteration 811, loss = 115830.41281015
# Validation score: 0.776133
# Iteration 812, loss = 115696.55994200
# Validation score: 0.776301
# Iteration 813, loss = 115624.17690375
# Validation score: 0.776671
# Iteration 814, loss = 115562.95746693
# Validation score: 0.777010
# Iteration 815, loss = 115482.32638682
# Validation score: 0.777679
# Iteration 816, loss = 115427.97667863
# Validation score: 0.778252
# Iteration 817, loss = 115358.10736611
# Validation score: 0.778449
# Iteration 818, loss = 115347.15803016
# Validation score: 0.778385
# Iteration 819, loss = 115203.41426018
# Validation score: 0.778376
# Iteration 820, loss = 115086.67741267
# Validation score: 0.778280
# Iteration 821, loss = 114983.17502687
# Validation score: 0.777586
# Iteration 822, loss = 114897.13445961
# Validation score: 0.776665
# Iteration 823, loss = 114882.17903810
# Validation score: 0.775953
# Iteration 824, loss = 114799.98853215
# Validation score: 0.775700
# Iteration 825, loss = 114917.14510988
# Validation score: 0.775683
# Iteration 826, loss = 114832.64323498
# Validation score: 0.776359
# Iteration 827, loss = 114684.35432642
# Validation score: 0.776654
# Iteration 828, loss = 114603.00141311
# Validation score: 0.776809
# Iteration 829, loss = 114588.83424102
# Validation score: 0.776531
# Iteration 830, loss = 114495.82185944
# Validation score: 0.776635
# Iteration 831, loss = 114505.62067238
# Validation score: 0.776131
# Iteration 832, loss = 114307.72258065
# Validation score: 0.776360
# Iteration 833, loss = 114317.73296963
# Validation score: 0.777052
# Iteration 834, loss = 114141.65069136
# Validation score: 0.777457
# Iteration 835, loss = 114033.92459409
# Validation score: 0.778206
# Iteration 836, loss = 113905.19840539
# Validation score: 0.779004
# Iteration 837, loss = 113806.76811711
# Validation score: 0.779952
# Iteration 838, loss = 113728.75158371
# Validation score: 0.780944
# Iteration 839, loss = 113759.07894731
# Validation score: 0.781818
# Iteration 840, loss = 113715.82152245
# Validation score: 0.781981
# Iteration 841, loss = 113623.27751788
# Validation score: 0.781819
# Iteration 842, loss = 113621.93273428
# Validation score: 0.781568
# Iteration 843, loss = 113485.36601844
# Validation score: 0.780926
# Iteration 844, loss = 113402.97948863
# Validation score: 0.780714
# Iteration 845, loss = 113255.73072162
# Validation score: 0.780452
# Iteration 846, loss = 113231.50302474
# Validation score: 0.780239
# Iteration 847, loss = 113128.94558593
# Validation score: 0.779883
# Iteration 848, loss = 113057.27048903
# Validation score: 0.779584
# Iteration 849, loss = 113116.96677234
# Validation score: 0.779534
# Iteration 850, loss = 112985.23497853
# Validation score: 0.779616
# Iteration 851, loss = 113003.66701706
# Validation score: 0.779843
# Iteration 852, loss = 112870.30695742
# Validation score: 0.780229
# Iteration 853, loss = 112777.57531716
# Validation score: 0.780573
# Iteration 854, loss = 112696.60410542
# Validation score: 0.780521
# Iteration 855, loss = 112598.25318099
# Validation score: 0.780602
# Iteration 856, loss = 112623.27527907
# Validation score: 0.780662
# Iteration 857, loss = 112494.53650185
# Validation score: 0.780491
# Iteration 858, loss = 112422.86787040
# Validation score: 0.780495
# Iteration 859, loss = 112388.82570638
# Validation score: 0.780765
# Iteration 860, loss = 112392.02703141
# Validation score: 0.781124
# Iteration 861, loss = 112269.86570557
# Validation score: 0.781859
# Validation score did not improve more than tol=0.000100 for 20 consecutive epochs. Stopping.
# MLPRegressor(alpha=0.001, early_stopping=True, hidden_layer_sizes=(1000, 500),
#              max_iter=2000, n_iter_no_change=20, random_state=42, verbose=True)

# %%
# Plot training loss curve
plt.plot(mlp_reg.loss_curve_,  label='Training Loss')
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Learning curver: Loss vs Iterations")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# - At the start, the loss is very high, but it drops sharply in the first few iterations, meaning the model is quickly learning basic patterns.
# - As iterations increase, the curve levels off, showing that the model is converging — improvements become smaller because it has already captured most of the learnable structure.
# - The final plateau indicates the model has reached a stable point: further training won’t reduce loss significantly unless you adjust hyperparameters (e.g., learning rate, hidden layers).

# %%
# Predictions
y_pred_mlp = mlp_reg.predict(X_test_reg_scaled)

print("\nfor neural network (MLP Regressor) ----------------------------->")
print(f"R² Score: {r2_score(Y_test_monthly, y_pred_mlp):.4f}")
print(f"Mean Absolute Error: {mean_absolute_error(Y_test_monthly, y_pred_mlp):.2f}")
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(Y_test_monthly, y_pred_mlp)):.2f}")
print(f"Number of iterations completed: {mlp_reg.n_iter_}")
# Out:
# for neural network (MLP Regressor) ----------------------------->
# R² Score: 0.7963
# Mean Absolute Error: 492.64
# Root Mean Squared Error: 612.46
# Number of iterations completed: 861

# %% [markdown]
# for neural network R² Score: 0.7963
# Mean Absolute Error: 492.64
# Root Mean Squared Error: 612.46
# Number of iterations completed: 861.... it is not comparing better in comparison to linear regression and random forest.

# %%
results = {
    "Model": ["Ridge Regression", "Random Forest Regressor", "Neural Network (MLP)"],
    "Features Used": [
        X_train_selected_ridge.shape[1],
        X_train_selected_rf.shape[1],
        X_train_reg_scaled.shape[1]
    ],
    "CV Score": [
        ridge_grid_search.best_score_,
        grid_search.best_score_,
        None
    ],
    "Test R²": [
        r2_score(Y_test_monthly, y_pred_rfe),
        r2_score(Y_test_monthly, Y_final_pred),
        r2_score(Y_test_monthly, y_pred_mlp)
    ],
    "Test RMSE": [
        np.sqrt(mean_squared_error(Y_test_monthly, y_pred_rfe)),
        np.sqrt(mean_squared_error(Y_test_monthly, Y_final_pred)),
        np.sqrt(mean_squared_error(Y_test_monthly, y_pred_mlp))
    ],
    "MAE": [
        mean_absolute_error(Y_test_monthly, y_pred_rfe),
        mean_absolute_error(Y_test_monthly, Y_final_pred),
        mean_absolute_error(Y_test_monthly, y_pred_mlp)
    ],
    "MSE": [
        mean_squared_error(Y_test_monthly, y_pred_rfe),
        mean_squared_error(Y_test_monthly, Y_final_pred),
        mean_squared_error(Y_test_monthly, y_pred_mlp)
    ]
}

comparison_df = pd.DataFrame(results)

print("\n Final Regression Model Comparison:\n")
print(comparison_df)
# Out:
#  Final Regression Model Comparison:
#
#                      Model  Features Used  CV Score   Test R²   Test RMSE  \
# 0         Ridge Regression              5  0.851319  0.843633  536.620016
# 1  Random Forest Regressor              5  0.893095  0.892501  444.935161
# 2     Neural Network (MLP)              7       NaN  0.796313  612.457025
#
#           MAE            MSE
# 0  426.547531  287961.041353
# 1  337.609246  197967.297275
# 2  492.639250  375103.607070
